# %% [markdown]
# ## **Pandas Essencial**
# **Prof. Dr. Samuel Martins (@hisamuka @xavecoding)** <br/>
# xavecoding: https://youtube.com/c/xavecoding <br/>
#
# Neste tutorial, vamos aprender o essencial da biblioteca _Pandas_ para manipulação de dados.<br/><br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# ### Pacotes usados neste Notebook

# %%
# pacotes usados neste notebook
import pandas as pd

# %% [markdown]
# <h1>Manipulação de Dados com Pandas</h1><hr/>

# %% [markdown]
# <h2>1. Manipulação Básica de Datasets</h2>
# <hr/>

# %% [markdown]
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil <br/>
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019**. <br/>
# Cada *amostra (registro/linha)* consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil. <br/>
# Alguns dos principais *atributos* (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.
#
#
# \* O arquivo disponibilizado no Kaggle está no formato *tsv*. Embora o _pandas_ consiga abrí-lo normalmente, convertemos tal arquivo para o formato *CSV*, que é um dos formatos mais utilizados, e mudamos seu separado para ';' apenas para mostrar algumas opções da função de carregamento.

# %% [markdown]
# ### 1.1. Importando o Dataset
# Para carregar um dataset no formato csv, basta utilizar a função `read_csv` do pandas. Por padrão, ela considera _','_ como separador.

# %%
data1 = pd.read_csv(r'C:\Users\Armando\Downloads\archive\2004-2021.tsv', delimiter = '\t')

# %% [markdown]
# O dataset não foi carregado corretamente pois o separador utilizado seu arquivo CSV era ';' e não a ','. <br/>
# Vamos então carregá-lo corretamente:

# %%
data1
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 120818   OLEO DIESEL S10                            12              R$/l
# 120819   OLEO DIESEL S10                           100              R$/l
# 120820   OLEO DIESEL S10                           886              R$/l
# 120821   OLEO DIESEL S10                            33              R$/l
# 120822   OLEO DIESEL S10                            18              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 120818                4.582                  0.056                 4.510
# 120819                4.141                  0.187                 3.838
# 120820                4.246                  0.216                 3.769
# 120821                4.464                  0.205                 4.190
# 120822                4.352                  0.156                 4.199
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 120818                 4.690             -99999.0                     0.012
# 120819                 4.739             -99999.0                     0.045
# 120820                 5.199             -99999.0                     0.051
# 120821                 4.699             -99999.0                     0.046
# 120822                 4.699             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 120818                 -99999.0                   -99999.0
# 120819                 -99999.0                   -99999.0
# 120820                 -99999.0                   -99999.0
# 120821                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 120818                  -99999.0                  -99999.0
# 120819                  -99999.0                  -99999.0
# 120820                  -99999.0                  -99999.0
# 120821                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                              0.133
# 1                              0.115
# 2                              0.098
# 3                              0.143
# 4                              0.082
# ...                              ...
# 120818                      -99999.0
# 120819                      -99999.0
# 120820                      -99999.0
# 120821                      -99999.0
# 120822                      -99999.0
#
# [120823 rows x 18 columns]

# %% [markdown]
# ### 1.2. Exibindo as primeiras linhas do Dataset
# A função `.head()` exibe as 5 primeiras linhas do dataset/tabela/Data Frame.

# %%
data1.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                         0.133
# 1                         0.115
# 2                         0.098
# 3                         0.143
# 4                         0.082

# %%
data1.tail()
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO          ESTADO          PRODUTO  \
# 120818   2021-04-25  2021-05-01     NORTE         RORAIMA  OLEO DIESEL S10
# 120819   2021-04-25  2021-05-01       SUL  SANTA CATARINA  OLEO DIESEL S10
# 120820   2021-04-25  2021-05-01   SUDESTE       SAO PAULO  OLEO DIESEL S10
# 120821   2021-04-25  2021-05-01  NORDESTE         SERGIPE  OLEO DIESEL S10
# 120822   2021-04-25  2021-05-01     NORTE       TOCANTINS  OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 120818                            12              R$/l                4.582
# 120819                           100              R$/l                4.141
# 120820                           886              R$/l                4.246
# 120821                            33              R$/l                4.464
# 120822                            18              R$/l                4.352
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 120818                  0.056                 4.510                 4.690
# 120819                  0.187                 3.838                 4.739
# 120820                  0.216                 3.769                 5.199
# 120821                  0.205                 4.190                 4.699
# 120822                  0.156                 4.199                 4.699
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 120818             -99999.0                     0.012
# 120819             -99999.0                     0.045
# 120820             -99999.0                     0.051
# 120821             -99999.0                     0.046
# 120822             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 120818                 -99999.0                   -99999.0
# 120819                 -99999.0                   -99999.0
# 120820                 -99999.0                   -99999.0
# 120821                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 120818                  -99999.0                  -99999.0
# 120819                  -99999.0                  -99999.0
# 120820                  -99999.0                  -99999.0
# 120821                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 120818                      -99999.0
# 120819                      -99999.0
# 120820                      -99999.0
# 120821                      -99999.0
# 120822                      -99999.0

# %% [markdown]
# ### 1.3 Informações do Dataset e Elementos Chave

# %% [markdown]
# ### 1.3.1 Informações gerais sobre o Dataset

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  object
#  1   DATA FINAL                     120823 non-null  object
#  2   REGIÃO                         120823 non-null  object
#  3   ESTADO                         120823 non-null  object
#  4   PRODUTO                        120823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  object
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           120823 non-null  object
#  12  COEF DE VARIAÇÃO REVENDA       120823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       120823 non-null  object
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     120823 non-null  object
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      120823 non-null  object
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      120823 non-null  object
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  120823 non-null  object
# dtypes: float64(5), int64(1), object(12)
# memory usage: 16.6+ MB

# %% [markdown]
# ### 1.3.2 Data Frame
# Todo dataset carregado (dados estruturados) é um `Data Frame`: 'Tabela' bi-dimensional, de tamanho mutável, com dados potencialmente heterogêneos. <br/>

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Podemos acessar as **dimensões do Data Frame** (número de linhas x número de colunas) utilizando o atributo `.shape` do Data Frame.

# %%
data1.shape
# Out:
# (120823, 18)

# %%
print(f'O datafre possui{data1.shape} Linhas e colunas, respectivamente')
# Out:
# O datafre possui(120823, 18) Linhas e colunas, respectivamente

# %% [markdown]
# #### **Criando um DataFrame**
#
# Podemos criar um DataFrame a partir de um _dicionário_, onde cada **chave** possui uma **lista de elementos de igual tamanho**.<br/>
# As **chaves** representam as **colunas** e **cada um dos valores de sua lista** representa o **valor da linha** correspondente para aquela coluna.

# %%
personagens_df = pd.DataFrame({
    'nome': ['Luke Skywalker', 'Yoda', 'Palpatine'],
    'idade': [16, 1000, 70],
    'peso': [70, 15, 60],
    'eh jedi': [True, True, False]  # o nome das colunas podem ter espaços
})

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %% [markdown]
# #### **VEJA MAIS**
# Criando um Data Frame a partir de um dicionário: https://www.geeksforgeeks.org/how-to-create-dataframe-from-dictionary-in-python-pandas/

# %% [markdown]
# #### **Renomeando as colunas de um DataFrame**
# **===>** O método `DataFrame.columns` retorna uma ";lista" com os **nomes de todas as colunas** do data frame.

# %%
personagens_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'eh jedi'], dtype='object')

# %%
list(personagens_df.columns)
# Out:
# ['nome', 'idade', 'peso', 'eh jedi']

# %% [markdown]
# <br/>
#
# **===>** Para **renomear colunas** do data frame, utilize o método `DataFrame.rename`, que retorna uma _cópia_ do data frame com as as colunas renomeadas:

# %%
personagens_df.rename(columns ={
    'nome':'jedi',
    'idade':'Idade',
}, inplace = True)

# %%
personagens_df
# Out:
#              jedi  Idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %% [markdown]
# <br/>
#
# **===>** Uma outra forma de **renomear todas as listas** de um data frame é passar uma _lista_ com os novos nomes das colunas para o atributo `DataFrame.columns`:

# %%
personagens_df = ['NOME', 'IDADE', 'PESO', 'EH JEDI']

# %%
personagens_df
# Out:
# ['NOME', 'IDADE', 'PESO', 'EH JEDI']

# %% [markdown]
# ### 1.3.3 Series

# %% [markdown]
# Array uni-dimensional com os dados e rótulos de um eixo.

# %%
data1.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                         0.133
# 1                         0.115
# 2                         0.098
# 3                         0.143
# 4                         0.082

# %%
data1['ESTADO']
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: object

# %%
data1.ESTADO
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: object

# %%
data1.iloc[0:3]
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   2004-05-09  2004-05-15  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
# 2                0.419                     0.070                     0.97
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                    0.9666                         0.133
# 1                      1.05                         0.115
# 2                     1.161                         0.098

# %%
type(data1.iloc[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### **Criando uma Series**
#
# Podemos criar um DataFrame a partir de uma lista de elementos.

# %%
pd.Series([5, 0.6, 0.3, 0.7])
# Out:
# 0    5.0
# 1    0.6
# 2    0.3
# 3    0.7
# dtype: float64

# %% [markdown]
# Podemos alterar o **nome dos índices** (veremos melhor jajá) e o **nome da Series** (o que ela representa):

# %%
pd.Series([5, 0.6, 0.3, 0.7], index= ['A', 'B', 'C', 'D'], name= 'Probabilidades')
# Out:
# A    5.0
# B    0.6
# C    0.3
# D    0.7
# Name: Probabilidades, dtype: float64

# %% [markdown]
# ### 1.3.4 Atribuindo Dados

# %% [markdown]
# #### 1.3.4.1 Atribuindo constantes

# %%
data1['PRODUTO'] #RETORNA UMA REFERÊNCIA, NÂO UMA CÓPIA!!!
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 120818     OLEO DIESEL S10
# 120819     OLEO DIESEL S10
# 120820     OLEO DIESEL S10
# 120821     OLEO DIESEL S10
# 120822     OLEO DIESEL S10
# Name: PRODUTO, Length: 120823, dtype: object

# %%
produto_copy = data1['PRODUTO'].copy()
produto_copy
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 120818     OLEO DIESEL S10
# 120819     OLEO DIESEL S10
# 120820     OLEO DIESEL S10
# 120821     OLEO DIESEL S10
# 120822     OLEO DIESEL S10
# Name: PRODUTO, Length: 120823, dtype: object

# %%
data1['PRODUTO'] = 'Combustivel'

# %%
data1
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       Combustivel                           127              R$/l
# 1       Combustivel                           387              R$/l
# 2       Combustivel                           192              R$/l
# 3       Combustivel                           162              R$/l
# 4       Combustivel                           103              R$/l
# ...             ...                           ...               ...
# 120818  Combustivel                            12              R$/l
# 120819  Combustivel                           100              R$/l
# 120820  Combustivel                           886              R$/l
# 120821  Combustivel                            33              R$/l
# 120822  Combustivel                            18              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 120818                4.582                  0.056                 4.510
# 120819                4.141                  0.187                 3.838
# 120820                4.246                  0.216                 3.769
# 120821                4.464                  0.205                 4.190
# 120822                4.352                  0.156                 4.199
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 120818                 4.690             -99999.0                     0.012
# 120819                 4.739             -99999.0                     0.045
# 120820                 5.199             -99999.0                     0.051
# 120821                 4.699             -99999.0                     0.046
# 120822                 4.699             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 120818                 -99999.0                   -99999.0
# 120819                 -99999.0                   -99999.0
# 120820                 -99999.0                   -99999.0
# 120821                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 120818                  -99999.0                  -99999.0
# 120819                  -99999.0                  -99999.0
# 120820                  -99999.0                  -99999.0
# 120821                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                              0.133
# 1                              0.115
# 2                              0.098
# 3                              0.143
# 4                              0.082
# ...                              ...
# 120818                      -99999.0
# 120819                      -99999.0
# 120820                      -99999.0
# 120821                      -99999.0
# 120822                      -99999.0
#
# [120823 rows x 18 columns]

# %%
data1['PRODUTO'] = produto_copy

# %%
data1
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 120818   OLEO DIESEL S10                            12              R$/l
# 120819   OLEO DIESEL S10                           100              R$/l
# 120820   OLEO DIESEL S10                           886              R$/l
# 120821   OLEO DIESEL S10                            33              R$/l
# 120822   OLEO DIESEL S10                            18              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 120818                4.582                  0.056                 4.510
# 120819                4.141                  0.187                 3.838
# 120820                4.246                  0.216                 3.769
# 120821                4.464                  0.205                 4.190
# 120822                4.352                  0.156                 4.199
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 120818                 4.690             -99999.0                     0.012
# 120819                 4.739             -99999.0                     0.045
# 120820                 5.199             -99999.0                     0.051
# 120821                 4.699             -99999.0                     0.046
# 120822                 4.699             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 120818                 -99999.0                   -99999.0
# 120819                 -99999.0                   -99999.0
# 120820                 -99999.0                   -99999.0
# 120821                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 120818                  -99999.0                  -99999.0
# 120819                  -99999.0                  -99999.0
# 120820                  -99999.0                  -99999.0
# 120821                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                              0.133
# 1                              0.115
# 2                              0.098
# 3                              0.143
# 4                              0.082
# ...                              ...
# 120818                      -99999.0
# 120819                      -99999.0
# 120820                      -99999.0
# 120821                      -99999.0
# 120822                      -99999.0
#
# [120823 rows x 18 columns]

# %% [markdown]
# #### 1.3.4.2 Atribuindo listas ou series

# %%
n_rows, n_cols = data1.shape
n_rows, n_cols
# Out:
# (120823, 18)

# %%
novos_produtos = [f'Produto {i}' for i in range(n_rows)]
len(novos_produtos)
# Out:
# 120823

# %%
data1['PRODUTO'] = novos_produtos

# %%
data1
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0            Produto 0                           127              R$/l
# 1            Produto 1                           387              R$/l
# 2            Produto 2                           192              R$/l
# 3            Produto 3                           162              R$/l
# 4            Produto 4                           103              R$/l
# ...                ...                           ...               ...
# 120818  Produto 120818                            12              R$/l
# 120819  Produto 120819                           100              R$/l
# 120820  Produto 120820                           886              R$/l
# 120821  Produto 120821                            33              R$/l
# 120822  Produto 120822                            18              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 120818                4.582                  0.056                 4.510
# 120819                4.141                  0.187                 3.838
# 120820                4.246                  0.216                 3.769
# 120821                4.464                  0.205                 4.190
# 120822                4.352                  0.156                 4.199
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 120818                 4.690             -99999.0                     0.012
# 120819                 4.739             -99999.0                     0.045
# 120820                 5.199             -99999.0                     0.051
# 120821                 4.699             -99999.0                     0.046
# 120822                 4.699             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 120818                 -99999.0                   -99999.0
# 120819                 -99999.0                   -99999.0
# 120820                 -99999.0                   -99999.0
# 120821                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 120818                  -99999.0                  -99999.0
# 120819                  -99999.0                  -99999.0
# 120820                  -99999.0                  -99999.0
# 120821                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                              0.133
# 1                              0.115
# 2                              0.098
# 3                              0.143
# 4                              0.082
# ...                              ...
# 120818                      -99999.0
# 120819                      -99999.0
# 120820                      -99999.0
# 120821                      -99999.0
# 120822                      -99999.0
#
# [120823 rows x 18 columns]

# %%
produto_copy
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 120818     OLEO DIESEL S10
# 120819     OLEO DIESEL S10
# 120820     OLEO DIESEL S10
# 120821     OLEO DIESEL S10
# 120822     OLEO DIESEL S10
# Name: PRODUTO, Length: 120823, dtype: object

# %%
data1['PRODUTOS'] = produto_copy

# %% [markdown]
# #### 1.3.4.3 Criando novas colunas
# Para **criar uma nova coluna** em um data frame, basta atribuirmos uma _lista/Series de valores_ a uma **nova 'chave'** do data frame. <br/>
#
# **PS:** A _quantidade de valores_ da lista precisa ser **igual** ao _número de linhas/registros_ do data frame.

# %%
data1['COLUNA SEM NOÇAO'] = 'DEFAULT'
data1
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0            Produto 0                           127              R$/l
# 1            Produto 1                           387              R$/l
# 2            Produto 2                           192              R$/l
# 3            Produto 3                           162              R$/l
# 4            Produto 4                           103              R$/l
# ...                ...                           ...               ...
# 120818  Produto 120818                            12              R$/l
# 120819  Produto 120819                           100              R$/l
# 120820  Produto 120820                           886              R$/l
# 120821  Produto 120821                            33              R$/l
# 120822  Produto 120822                            18              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 120818                4.582                  0.056                 4.510
# 120819                4.141                  0.187                 3.838
# 120820                4.246                  0.216                 3.769
# 120821                4.464                  0.205                 4.190
# 120822                4.352                  0.156                 4.199
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 120818                 4.690             -99999.0                     0.012
# 120819                 4.739             -99999.0                     0.045
# 120820                 5.199             -99999.0                     0.051
# 120821                 4.699             -99999.0                     0.046
# 120822                 4.699             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 120818                 -99999.0                   -99999.0
# 120819                 -99999.0                   -99999.0
# 120820                 -99999.0                   -99999.0
# 120821                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 120818                  -99999.0                  -99999.0
# 120819                  -99999.0                  -99999.0
# 120820                  -99999.0                  -99999.0
# 120821                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO          PRODUTOS COLUNA SEM NOÇAO
# 0                              0.133  ETANOL HIDRATADO          DEFAULT
# 1                              0.115  ETANOL HIDRATADO          DEFAULT
# 2                              0.098  ETANOL HIDRATADO          DEFAULT
# 3                              0.143  ETANOL HIDRATADO          DEFAULT
# 4                              0.082  ETANOL HIDRATADO          DEFAULT
# ...                              ...               ...              ...
# 120818                      -99999.0   OLEO DIESEL S10          DEFAULT
# 120819                      -99999.0   OLEO DIESEL S10          DEFAULT
# 120820                      -99999.0   OLEO DIESEL S10          DEFAULT
# 120821                      -99999.0   OLEO DIESEL S10          DEFAULT
# 120822                      -99999.0   OLEO DIESEL S10          DEFAULT
#
# [120823 rows x 20 columns]

# %%
data1['COLUNA SEM NOÇAO'] = range(n_rows)

# %%
data1
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0            Produto 0                           127              R$/l
# 1            Produto 1                           387              R$/l
# 2            Produto 2                           192              R$/l
# 3            Produto 3                           162              R$/l
# 4            Produto 4                           103              R$/l
# ...                ...                           ...               ...
# 120818  Produto 120818                            12              R$/l
# 120819  Produto 120819                           100              R$/l
# 120820  Produto 120820                           886              R$/l
# 120821  Produto 120821                            33              R$/l
# 120822  Produto 120822                            18              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 120818                4.582                  0.056                 4.510
# 120819                4.141                  0.187                 3.838
# 120820                4.246                  0.216                 3.769
# 120821                4.464                  0.205                 4.190
# 120822                4.352                  0.156                 4.199
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 120818                 4.690             -99999.0                     0.012
# 120819                 4.739             -99999.0                     0.045
# 120820                 5.199             -99999.0                     0.051
# 120821                 4.699             -99999.0                     0.046
# 120822                 4.699             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 120818                 -99999.0                   -99999.0
# 120819                 -99999.0                   -99999.0
# 120820                 -99999.0                   -99999.0
# 120821                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 120818                  -99999.0                  -99999.0
# 120819                  -99999.0                  -99999.0
# 120820                  -99999.0                  -99999.0
# 120821                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO          PRODUTOS  COLUNA SEM NOÇAO
# 0                              0.133  ETANOL HIDRATADO                 0
# 1                              0.115  ETANOL HIDRATADO                 1
# 2                              0.098  ETANOL HIDRATADO                 2
# 3                              0.143  ETANOL HIDRATADO                 3
# 4                              0.082  ETANOL HIDRATADO                 4
# ...                              ...               ...               ...
# 120818                      -99999.0   OLEO DIESEL S10            120818
# 120819                      -99999.0   OLEO DIESEL S10            120819
# 120820                      -99999.0   OLEO DIESEL S10            120820
# 120821                      -99999.0   OLEO DIESEL S10            120821
# 120822                      -99999.0   OLEO DIESEL S10            120822
#
# [120823 rows x 20 columns]

# %% [markdown]
# <br/>
#
# Outro exemplo:

# %%
data1['PREÇO MÉDIA REVENDA EM DOLARES'] = data1['PREÇO MÉDIO REVENDA'] * 5

# %%
data1
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0            Produto 0                           127              R$/l
# 1            Produto 1                           387              R$/l
# 2            Produto 2                           192              R$/l
# 3            Produto 3                           162              R$/l
# 4            Produto 4                           103              R$/l
# ...                ...                           ...               ...
# 120818  Produto 120818                            12              R$/l
# 120819  Produto 120819                           100              R$/l
# 120820  Produto 120820                           886              R$/l
# 120821  Produto 120821                            33              R$/l
# 120822  Produto 120822                            18              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 120818                4.582                  0.056                 4.510  ...
# 120819                4.141                  0.187                 3.838  ...
# 120820                4.246                  0.216                 3.769  ...
# 120821                4.464                  0.205                 4.190  ...
# 120822                4.352                  0.156                 4.199  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                    0.012
# 1                      0.399                    0.098
# 2                      0.419                    0.070
# 3                      0.432                    0.055
# 4                       0.24                    0.066
# ...                      ...                      ...
# 120818              -99999.0                    0.012
# 120819              -99999.0                    0.045
# 120820              -99999.0                    0.051
# 120821              -99999.0                    0.046
# 120822              -99999.0                    0.036
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 120818                  -99999.0                   -99999.0
# 120819                  -99999.0                   -99999.0
# 120820                  -99999.0                   -99999.0
# 120821                  -99999.0                   -99999.0
# 120822                  -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 120818                  -99999.0                  -99999.0
# 120819                  -99999.0                  -99999.0
# 120820                  -99999.0                  -99999.0
# 120821                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO          PRODUTOS COLUNA SEM NOÇAO  \
# 0                              0.133  ETANOL HIDRATADO                0
# 1                              0.115  ETANOL HIDRATADO                1
# 2                              0.098  ETANOL HIDRATADO                2
# 3                              0.143  ETANOL HIDRATADO                3
# 4                              0.082  ETANOL HIDRATADO                4
# ...                              ...               ...              ...
# 120818                      -99999.0   OLEO DIESEL S10           120818
# 120819                      -99999.0   OLEO DIESEL S10           120819
# 120820                      -99999.0   OLEO DIESEL S10           120820
# 120821                      -99999.0   OLEO DIESEL S10           120821
# 120822                      -99999.0   OLEO DIESEL S10           120822
#
#         PREÇO MÉDIA REVENDA EM DOLARES
# 0                                6.440
# 1                                5.810
# 2                                6.945
# 3                                6.310
# 4                                5.905
# ...                                ...
# 120818                          22.910
# 120819                          20.705
# 120820                          21.230
# 120821                          22.320
# 120822                          21.760
#
# [120823 rows x 21 columns]

# %% [markdown]
# **PS:** Obviamente, a lógica correta em converter o preço dos combustíveis em reais para dólares não é considerar uma taxa de câmbio fixa, uma vez que cada preço foi aferido em um momento diferente.

# %% [markdown]
# ### 1.3.4 Índices

# %% [markdown]
# Todo Data Frame possui **índices**, que não são considerado colunas da tabela. Tais índices são comumente **númericos**, de 0 a num_linhas-1, mas também podem ser **textuais (rótulos/labels)**.

# %%
data1.index
# Out:
# RangeIndex(start=0, stop=120823, step=1)

# %% [markdown]
# Use `list(data.index)` ou `data.index.to_list()` para converter um RangeIndex para uma python list.

# %% [markdown]
# #### **Exemplo de Data Frame com Índices Textuais (labels)**

# %%
pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=['XboxOne', 'Playstation4', 'Switch'])

# %%
pesquisa_de_satisfacao.head()
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %% [markdown]
# ### 1.4 Selecionando uma ou mais amostras (Indexação)

# %% [markdown]
# #### **==>  Index-based selection (seleção baseada em Índices)**
# Mostrando linhas específicas de um DataFrame:
#
# `iloc`: seleciona elementos do Dataframe, baseado em seu **índice (número)** --> row-first, column-second

# %% [markdown]
# **Selecionando uma amostra/linha:**

# %%
data1.iloc[1]
# Out:
# DATA INICIAL                            2004-05-09
# DATA FINAL                              2004-05-15
# REGIÃO                                CENTRO OESTE
# ESTADO                                       GOIAS
# PRODUTO                                  Produto 1
# NÚMERO DE POSTOS PESQUISADOS                   387
# UNIDADE DE MEDIDA                             R$/l
# PREÇO MÉDIO REVENDA                          1.162
# DESVIO PADRÃO REVENDA                        0.114
# PREÇO MÍNIMO REVENDA                          0.89
# PREÇO MÁXIMO REVENDA                         1.449
# MARGEM MÉDIA REVENDA                         0.399
# COEF DE VARIAÇÃO REVENDA                     0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                     0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                   0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                   0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                     1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO                0.115
# PRODUTOS                          ETANOL HIDRATADO
# COLUNA SEM NOÇAO                                 1
# PREÇO MÉDIA REVENDA EM DOLARES                5.81
# Name: 1, dtype: object

# %% [markdown]
# **Selecionando múltiplias amostras/linhas:**

# %%
data1.iloc[:, :4]
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
# [120823 rows x 4 columns]

# %%
data1.iloc[[1, 5, 10, 15]]
# Out:
#    DATA INICIAL  DATA FINAL        REGIÃO    ESTADO     PRODUTO  \
# 1    2004-05-09  2004-05-15  CENTRO OESTE     GOIAS   Produto 1
# 5    2004-05-09  2004-05-15      NORDESTE     BAHIA   Produto 5
# 10   2004-05-09  2004-05-15      NORDESTE     PIAUI  Produto 10
# 15   2004-05-09  2004-05-15         NORTE  AMAZONAS  Produto 15
#
#     NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1                            387              R$/l                1.162
# 5                            408              R$/l                1.383
# 10                            89              R$/l                1.573
# 15                            53              R$/l                1.578
#
#     DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 1                   0.114                 0.890  ...                 0.399
# 5                   0.132                 0.999  ...                 0.426
# 10                  0.134                 1.400  ...                 0.494
# 15                  0.123                 1.280  ...                 0.441
#
#    COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                     0.098                     0.763
# 5                     0.095                     0.957
# 10                    0.085                     1.079
# 15                    0.078                     1.137
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1                       0.088                    0.5013
# 5                       0.128                    0.5686
# 10                      0.078                    0.8857
# 15                      0.068                    0.9515
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO          PRODUTOS  \
# 1                       1.05                         0.115  ETANOL HIDRATADO
# 5                       1.35                         0.134  ETANOL HIDRATADO
# 10                    1.2499                         0.072  ETANOL HIDRATADO
# 15                    1.2109                          0.06  ETANOL HIDRATADO
#
#    COLUNA SEM NOÇAO  PREÇO MÉDIA REVENDA EM DOLARES
# 1                 1                           5.810
# 5                 5                           6.915
# 10               10                           7.865
# 15               15                           7.890
#
# [4 rows x 21 columns]

# %%
data1.iloc[[1, 3, 2]]
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO    PRODUTO  \
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS  Produto 1
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  Produto 3
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO  Produto 2
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1                           387              R$/l                1.162
# 3                           162              R$/l                1.262
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 1                  0.114                  0.89  ...                 0.399
# 3                  0.070                  1.09  ...                 0.432
# 2                  0.097                  1.18  ...                 0.419
#
#   COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                    0.098                     0.763
# 3                    0.055                      0.83
# 2                    0.070                      0.97
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1                      0.088                    0.5013
# 3                      0.119                    0.5991
# 2                      0.095                    0.5614
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO          PRODUTOS  \
# 1                      1.05                         0.115  ETANOL HIDRATADO
# 3                   1.22242                         0.143  ETANOL HIDRATADO
# 2                     1.161                         0.098  ETANOL HIDRATADO
#
#   COLUNA SEM NOÇAO  PREÇO MÉDIA REVENDA EM DOLARES
# 1                1                           5.810
# 3                3                           6.310
# 2                2                           6.945
#
# [3 rows x 21 columns]

# %%
data1.iloc[1, 2]
# Out:
# 'CENTRO OESTE'

# %% [markdown]
# #### **==>  Label-based selection (seleção baseadas em Rótulos)**
#
# `loc`: seleciona elementos do Dataframe, baseado em seus **rótulos** --> row-first, column-second

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.iloc[0]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
pesquisa_de_satisfacao.loc['Playstation4', 'ruim']
# Out:
# 2

# %% [markdown]
# ### 1.5 Selecionando um ou mais atributos (colunas)

# %%
data1['ESTADO']
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: object

# %%
data1.ESTADO
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: object

# %%
data1.loc[:, 'ESTADO']
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: object

# %%
data1[['PRODUTO', 'ESTADO', 'REGIÃO']]
# Out:
#                  PRODUTO              ESTADO        REGIÃO
# 0       ETANOL HIDRATADO    DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO               GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO         MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO  MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO             ALAGOAS      NORDESTE
# ...                  ...                 ...           ...
# 120818   OLEO DIESEL S10             RORAIMA         NORTE
# 120819   OLEO DIESEL S10      SANTA CATARINA           SUL
# 120820   OLEO DIESEL S10           SAO PAULO       SUDESTE
# 120821   OLEO DIESEL S10             SERGIPE      NORDESTE
# 120822   OLEO DIESEL S10           TOCANTINS         NORTE
#
# [120823 rows x 3 columns]

# %% [markdown]
# Como o rótulo da coluna 'DATA INICIAL' **possui espaço**, não é possível acessá-la como método: `data.DATA INICIAL`

# %% [markdown]
# ### 1.6 Removendo um Atributo (Coluna) do Data Frame

# %%
data1
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 120818   OLEO DIESEL S10                            12              R$/l
# 120819   OLEO DIESEL S10                           100              R$/l
# 120820   OLEO DIESEL S10                           886              R$/l
# 120821   OLEO DIESEL S10                            33              R$/l
# 120822   OLEO DIESEL S10                            18              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 120818                4.582                  0.056                 4.510
# 120819                4.141                  0.187                 3.838
# 120820                4.246                  0.216                 3.769
# 120821                4.464                  0.205                 4.190
# 120822                4.352                  0.156                 4.199
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 120818                 4.690             -99999.0                     0.012
# 120819                 4.739             -99999.0                     0.045
# 120820                 5.199             -99999.0                     0.051
# 120821                 4.699             -99999.0                     0.046
# 120822                 4.699             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 120818                 -99999.0                   -99999.0
# 120819                 -99999.0                   -99999.0
# 120820                 -99999.0                   -99999.0
# 120821                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 120818                  -99999.0                  -99999.0
# 120819                  -99999.0                  -99999.0
# 120820                  -99999.0                  -99999.0
# 120821                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                              0.133
# 1                              0.115
# 2                              0.098
# 3                              0.143
# 4                              0.082
# ...                              ...
# 120818                      -99999.0
# 120819                      -99999.0
# 120820                      -99999.0
# 120821                      -99999.0
# 120822                      -99999.0
#
# [120823 rows x 18 columns]

# %%
del data1['ESTADO']

# %%
data1
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO           PRODUTO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 1        2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 2        2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 4        2004-05-09  2004-05-15      NORDESTE  ETANOL HIDRATADO
# ...             ...         ...           ...               ...
# 120818   2021-04-25  2021-05-01         NORTE   OLEO DIESEL S10
# 120819   2021-04-25  2021-05-01           SUL   OLEO DIESEL S10
# 120820   2021-04-25  2021-05-01       SUDESTE   OLEO DIESEL S10
# 120821   2021-04-25  2021-05-01      NORDESTE   OLEO DIESEL S10
# 120822   2021-04-25  2021-05-01         NORTE   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                                127              R$/l                1.288
# 1                                387              R$/l                1.162
# 2                                192              R$/l                1.389
# 3                                162              R$/l                1.262
# 4                                103              R$/l                1.181
# ...                              ...               ...                  ...
# 120818                            12              R$/l                4.582
# 120819                           100              R$/l                4.141
# 120820                           886              R$/l                4.246
# 120821                            33              R$/l                4.464
# 120822                            18              R$/l                4.352
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                       0.016                 1.190                 1.350
# 1                       0.114                 0.890                 1.449
# 2                       0.097                 1.180                 1.760
# 3                       0.070                 1.090                 1.509
# 4                       0.078                 1.050                 1.400
# ...                       ...                   ...                   ...
# 120818                  0.056                 4.510                 4.690
# 120819                  0.187                 3.838                 4.739
# 120820                  0.216                 3.769                 5.199
# 120821                  0.205                 4.190                 4.699
# 120822                  0.156                 4.199                 4.699
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                     0.463                     0.012
# 1                     0.399                     0.098
# 2                     0.419                     0.070
# 3                     0.432                     0.055
# 4                      0.24                     0.066
# ...                     ...                       ...
# 120818             -99999.0                     0.012
# 120819             -99999.0                     0.045
# 120820             -99999.0                     0.051
# 120821             -99999.0                     0.046
# 120822             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 120818                 -99999.0                   -99999.0
# 120819                 -99999.0                   -99999.0
# 120820                 -99999.0                   -99999.0
# 120821                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 120818                  -99999.0                  -99999.0
# 120819                  -99999.0                  -99999.0
# 120820                  -99999.0                  -99999.0
# 120821                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                              0.133
# 1                              0.115
# 2                              0.098
# 3                              0.143
# 4                              0.082
# ...                              ...
# 120818                      -99999.0
# 120819                      -99999.0
# 120820                      -99999.0
# 120821                      -99999.0
# 120822                      -99999.0
#
# [120823 rows x 17 columns]

# %% [markdown]
# ### 1.7 Salvando um Data Frame

# %% [markdown]
# Para salvarmos um Data Frame para um **arquivo CSV**, basta usarmos o método `.to_csv`. <br/>
# Por padrão, esse método **salva os índices da tabela como uma coluna no CSV**.<br/>
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso (veja que removemos anteriormente a coluna 'Unnamed: 0' que foi justamente esse caso).<br/>
# Desta forma, utilize o parâmetro: `index=False`.
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro `sep`.

# %%
data1.to_csv(r'C:\Users\Armando\Desktop\preprocessado')

# %% [markdown]
# ### 1.8 Seleção Condicional: Filtrando amostras

# %% [markdown]
# Durante nossas análise exploratórias, frequentemente filtraremos nossas amostras, a partir de certas **condições**, para fins de análise mais específica. <br/>
# Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nosso dataset pré-processado que salvamos no item anterior.

# %%
data = pd.read_csv(r'C:\Users\Armando\Desktop\preprocessado')
del data['Unnamed: 0']

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 2   2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 4   2004-05-09  2004-05-15      NORDESTE  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
# 3                           162              R$/l                1.262
# 4                           103              R$/l                1.181
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
# 3                  0.070                  1.09                 1.509
# 4                  0.078                  1.05                 1.400
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
# 2                0.419                     0.070                     0.97
# 3                0.432                     0.055                     0.83
# 4                 0.24                     0.066                    0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                    0.9666                         0.133
# 1                      1.05                         0.115
# 2                     1.161                         0.098
# 3                   1.22242                         0.143
# 4                    1.0317                         0.082

# %%
data['REGIÃO'].unique()
# Out:
# array(['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'],
#       dtype=object)

# %% [markdown]
# #### **Selecionando apenas os preços dos Postos de São Paulo**

# %% [markdown]
# ##### **==> Alternativa 1: Seleção Condicional (Comparações diretas)**

# %% [markdown]
# O código abaixo retorna uma ***Series ('array') de booleans***, com o número de linhas (amostras) do Data Frame, que informa os registros de preços dos postos do _estado de São Paulo_ (True).

# %%
selecoes = data['REGIÃO'] == 'NORTE'

# %%
selecoes
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 120818     True
# 120819    False
# 120820    False
# 120821    False
# 120822     True
# Name: REGIÃO, Length: 120823, dtype: bool

# %%
selecoes.shape
# Out:
# (120823,)

# %% [markdown]
# Para **filtrarmos** os registros de postos do estado de São Paulo:

# %%
data[selecoes]
# Out:
#        DATA INICIAL  DATA FINAL REGIÃO           PRODUTO  \
# 13       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 14       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 15       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 16       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 17       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# ...             ...         ...    ...               ...
# 120799   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120809   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120817   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120818   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120822   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 13                                33              R$/l                1.805
# 14                                15              R$/l                1.785
# 15                                53              R$/l                1.578
# 16                               104              R$/l                1.914
# 17                                97              R$/l                1.545
# ...                              ...               ...                  ...
# 120799                            44              R$/l                4.332
# 120809                            40              R$/l                4.447
# 120817                            30              R$/l                4.503
# 120818                            12              R$/l                4.582
# 120822                            18              R$/l                4.352
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 13                      0.134                 1.500                 1.980
# 14                      0.035                 1.740                 1.850
# 15                      0.123                 1.280                 1.850
# 16                      0.246                 1.270                 2.400
# 17                      0.141                 1.250                 1.990
# ...                       ...                   ...                   ...
# 120799                  0.274                 3.990                 4.990
# 120809                  0.265                 3.950                 5.050
# 120817                  0.157                 4.250                 4.799
# 120818                  0.056                 4.510                 4.690
# 120822                  0.156                 4.199                 4.699
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 13                    0.689                     0.074
# 14                    0.412                     0.020
# 15                    0.441                     0.078
# 16                    0.536                     0.129
# 17                    0.533                     0.091
# ...                     ...                       ...
# 120799             -99999.0                     0.063
# 120809             -99999.0                     0.060
# 120817             -99999.0                     0.035
# 120818             -99999.0                     0.012
# 120822             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 13                        1.116                      0.171
# 14                        1.373                      0.167
# 15                        1.137                      0.068
# 16                        1.378                      0.237
# 17                        1.012                      0.149
# ...                         ...                        ...
# 120799                 -99999.0                   -99999.0
# 120809                 -99999.0                   -99999.0
# 120817                 -99999.0                   -99999.0
# 120818                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 13                         0.767                    1.2992
# 14                        0.8339                    1.4912
# 15                        0.9515                    1.2109
# 16                        0.7564                    1.8908
# 17                          0.52                    1.3306
# ...                          ...                       ...
# 120799                  -99999.0                  -99999.0
# 120809                  -99999.0                  -99999.0
# 120817                  -99999.0                  -99999.0
# 120818                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 13                             0.153
# 14                             0.122
# 15                              0.06
# 16                             0.172
# 17                             0.147
# ...                              ...
# 120799                      -99999.0
# 120809                      -99999.0
# 120817                      -99999.0
# 120818                      -99999.0
# 120822                      -99999.0
#
# [27989 rows x 17 columns]

# %% [markdown]
# O resultado é um Data Frame com _apenas_ os registros desejados após a **filtragem**.<br/>
# Podemos ainda utilizar o método `loc` para o mesmo fim:

# %%
data.loc[selecoes]
# Out:
#        DATA INICIAL  DATA FINAL REGIÃO           PRODUTO  \
# 13       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 14       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 15       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 16       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 17       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# ...             ...         ...    ...               ...
# 120799   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120809   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120817   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120818   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120822   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 13                                33              R$/l                1.805
# 14                                15              R$/l                1.785
# 15                                53              R$/l                1.578
# 16                               104              R$/l                1.914
# 17                                97              R$/l                1.545
# ...                              ...               ...                  ...
# 120799                            44              R$/l                4.332
# 120809                            40              R$/l                4.447
# 120817                            30              R$/l                4.503
# 120818                            12              R$/l                4.582
# 120822                            18              R$/l                4.352
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 13                      0.134                 1.500                 1.980
# 14                      0.035                 1.740                 1.850
# 15                      0.123                 1.280                 1.850
# 16                      0.246                 1.270                 2.400
# 17                      0.141                 1.250                 1.990
# ...                       ...                   ...                   ...
# 120799                  0.274                 3.990                 4.990
# 120809                  0.265                 3.950                 5.050
# 120817                  0.157                 4.250                 4.799
# 120818                  0.056                 4.510                 4.690
# 120822                  0.156                 4.199                 4.699
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 13                    0.689                     0.074
# 14                    0.412                     0.020
# 15                    0.441                     0.078
# 16                    0.536                     0.129
# 17                    0.533                     0.091
# ...                     ...                       ...
# 120799             -99999.0                     0.063
# 120809             -99999.0                     0.060
# 120817             -99999.0                     0.035
# 120818             -99999.0                     0.012
# 120822             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 13                        1.116                      0.171
# 14                        1.373                      0.167
# 15                        1.137                      0.068
# 16                        1.378                      0.237
# 17                        1.012                      0.149
# ...                         ...                        ...
# 120799                 -99999.0                   -99999.0
# 120809                 -99999.0                   -99999.0
# 120817                 -99999.0                   -99999.0
# 120818                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 13                         0.767                    1.2992
# 14                        0.8339                    1.4912
# 15                        0.9515                    1.2109
# 16                        0.7564                    1.8908
# 17                          0.52                    1.3306
# ...                          ...                       ...
# 120799                  -99999.0                  -99999.0
# 120809                  -99999.0                  -99999.0
# 120817                  -99999.0                  -99999.0
# 120818                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 13                             0.153
# 14                             0.122
# 15                              0.06
# 16                             0.172
# 17                             0.147
# ...                              ...
# 120799                      -99999.0
# 120809                      -99999.0
# 120817                      -99999.0
# 120818                      -99999.0
# 120822                      -99999.0
#
# [27989 rows x 17 columns]

# %% [markdown]
# ##### **==> Alternativa 2: Utilizando o método `query`**

# %% [markdown]
# `query` filtra linhas de um DataFrame baseado em uma **query (pergunta)**.

# %%
data.query('REGIÃO == "NORTE"')
# Out:
#        DATA INICIAL  DATA FINAL REGIÃO           PRODUTO  \
# 13       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 14       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 15       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 16       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 17       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# ...             ...         ...    ...               ...
# 120799   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120809   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120817   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120818   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120822   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 13                                33              R$/l                1.805
# 14                                15              R$/l                1.785
# 15                                53              R$/l                1.578
# 16                               104              R$/l                1.914
# 17                                97              R$/l                1.545
# ...                              ...               ...                  ...
# 120799                            44              R$/l                4.332
# 120809                            40              R$/l                4.447
# 120817                            30              R$/l                4.503
# 120818                            12              R$/l                4.582
# 120822                            18              R$/l                4.352
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 13                      0.134                 1.500                 1.980
# 14                      0.035                 1.740                 1.850
# 15                      0.123                 1.280                 1.850
# 16                      0.246                 1.270                 2.400
# 17                      0.141                 1.250                 1.990
# ...                       ...                   ...                   ...
# 120799                  0.274                 3.990                 4.990
# 120809                  0.265                 3.950                 5.050
# 120817                  0.157                 4.250                 4.799
# 120818                  0.056                 4.510                 4.690
# 120822                  0.156                 4.199                 4.699
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 13                    0.689                     0.074
# 14                    0.412                     0.020
# 15                    0.441                     0.078
# 16                    0.536                     0.129
# 17                    0.533                     0.091
# ...                     ...                       ...
# 120799             -99999.0                     0.063
# 120809             -99999.0                     0.060
# 120817             -99999.0                     0.035
# 120818             -99999.0                     0.012
# 120822             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 13                        1.116                      0.171
# 14                        1.373                      0.167
# 15                        1.137                      0.068
# 16                        1.378                      0.237
# 17                        1.012                      0.149
# ...                         ...                        ...
# 120799                 -99999.0                   -99999.0
# 120809                 -99999.0                   -99999.0
# 120817                 -99999.0                   -99999.0
# 120818                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 13                         0.767                    1.2992
# 14                        0.8339                    1.4912
# 15                        0.9515                    1.2109
# 16                        0.7564                    1.8908
# 17                          0.52                    1.3306
# ...                          ...                       ...
# 120799                  -99999.0                  -99999.0
# 120809                  -99999.0                  -99999.0
# 120817                  -99999.0                  -99999.0
# 120818                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 13                             0.153
# 14                             0.122
# 15                              0.06
# 16                             0.172
# 17                             0.147
# ...                              ...
# 120799                      -99999.0
# 120809                      -99999.0
# 120817                      -99999.0
# 120818                      -99999.0
# 120822                      -99999.0
#
# [27989 rows x 17 columns]

# %% [markdown]
# <br/>
#
# Uma boa prática é **salvar o Data Frame filtrado em uma nova variável**. Isso simplifica a complexidade do código para futuras análise feita para os postos de São Paulo.

# %%
postos_norte = data.query('REGIÃO == "NORTE"')

# %%
postos_norte.reset_index(drop=True, inplace = True)

# %%
postos_norte
# Out:
#       DATA INICIAL  DATA FINAL REGIÃO           PRODUTO  \
# 0       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 1       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 2       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 3       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 4       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# ...            ...         ...    ...               ...
# 27984   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 27985   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 27986   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 27987   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 27988   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                                33              R$/l                1.805
# 1                                15              R$/l                1.785
# 2                                53              R$/l                1.578
# 3                               104              R$/l                1.914
# 4                                97              R$/l                1.545
# ...                             ...               ...                  ...
# 27984                            44              R$/l                4.332
# 27985                            40              R$/l                4.447
# 27986                            30              R$/l                4.503
# 27987                            12              R$/l                4.582
# 27988                            18              R$/l                4.352
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                      0.134                 1.500                 1.980
# 1                      0.035                 1.740                 1.850
# 2                      0.123                 1.280                 1.850
# 3                      0.246                 1.270                 2.400
# 4                      0.141                 1.250                 1.990
# ...                      ...                   ...                   ...
# 27984                  0.274                 3.990                 4.990
# 27985                  0.265                 3.950                 5.050
# 27986                  0.157                 4.250                 4.799
# 27987                  0.056                 4.510                 4.690
# 27988                  0.156                 4.199                 4.699
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                    0.689                     0.074                    1.116
# 1                    0.412                     0.020                    1.373
# 2                    0.441                     0.078                    1.137
# 3                    0.536                     0.129                    1.378
# 4                    0.533                     0.091                    1.012
# ...                    ...                       ...                      ...
# 27984             -99999.0                     0.063                 -99999.0
# 27985             -99999.0                     0.060                 -99999.0
# 27986             -99999.0                     0.035                 -99999.0
# 27987             -99999.0                     0.012                 -99999.0
# 27988             -99999.0                     0.036                 -99999.0
#
#       DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                          0.171                     0.767
# 1                          0.167                    0.8339
# 2                          0.068                    0.9515
# 3                          0.237                    0.7564
# 4                          0.149                      0.52
# ...                          ...                       ...
# 27984                   -99999.0                  -99999.0
# 27985                   -99999.0                  -99999.0
# 27986                   -99999.0                  -99999.0
# 27987                   -99999.0                  -99999.0
# 27988                   -99999.0                  -99999.0
#
#       PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                        1.2992                         0.153
# 1                        1.4912                         0.122
# 2                        1.2109                          0.06
# 3                        1.8908                         0.172
# 4                        1.3306                         0.147
# ...                         ...                           ...
# 27984                  -99999.0                      -99999.0
# 27985                  -99999.0                      -99999.0
# 27986                  -99999.0                      -99999.0
# 27987                  -99999.0                      -99999.0
# 27988                  -99999.0                      -99999.0
#
# [27989 rows x 17 columns]

# %% [markdown]
# #### **Selecionando registros de postos do Rio de Janeiro com Preços acima de 2 reais**

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 2   2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 4   2004-05-09  2004-05-15      NORDESTE  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
# 3                           162              R$/l                1.262
# 4                           103              R$/l                1.181
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
# 3                  0.070                  1.09                 1.509
# 4                  0.078                  1.05                 1.400
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
# 2                0.419                     0.070                     0.97
# 3                0.432                     0.055                     0.83
# 4                 0.24                     0.066                    0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                    0.9666                         0.133
# 1                      1.05                         0.115
# 2                     1.161                         0.098
# 3                   1.22242                         0.143
# 4                    1.0317                         0.082

# %%
data['REGIÃO'].unique()
# Out:
# array(['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'],
#       dtype=object)

# %%
data['REGIÃO'] == 'NORTE'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 120818     True
# 120819    False
# 120820    False
# 120821    False
# 120822     True
# Name: REGIÃO, Length: 120823, dtype: bool

# %%
data['PREÇO MÉDIO REVENDA'] > 2
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 120818     True
# 120819     True
# 120820     True
# 120821     True
# 120822     True
# Name: PREÇO MÉDIO REVENDA, Length: 120823, dtype: bool

# %%
selecao = (data['REGIÃO'] == 'NORTE') & (data['PREÇO MÉDIO REVENDA'] > 2)
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 120818     True
# 120819    False
# 120820    False
# 120821    False
# 120822     True
# Length: 120823, dtype: bool

# %% [markdown]
# Note que o resultado da seleção continua sendo uma _Series de booleans_ com o _mesmo número de linhas/amostras do DataFrame_, de modo que cada linha possuirá um valor booleano indicando se o posto é do Rio de Janeiro e o preço aferido do combustível é maior que 2 reais (True) ou não.
#
# O símbolo **&** significa **AND** na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&). <br/>
# Similarmente:
# - **|** representa o **OR** (não é ||)
# - **~** representa o **NOT** (não é !)

# %%
data[selecao].reset_index(drop=True)
# Out:
#       DATA INICIAL  DATA FINAL REGIÃO           PRODUTO  \
# 0       2004-11-21  2004-11-27  NORTE  ETANOL HIDRATADO
# 1       2004-11-21  2004-11-27  NORTE  ETANOL HIDRATADO
# 2       2004-11-21  2004-11-27  NORTE  ETANOL HIDRATADO
# 3       2004-11-28  2004-12-04  NORTE  ETANOL HIDRATADO
# 4       2004-11-28  2004-12-04  NORTE  ETANOL HIDRATADO
# ...            ...         ...    ...               ...
# 25624   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 25625   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 25626   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 25627   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 25628   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                                11              R$/l                2.004
# 1                                98              R$/l                2.011
# 2                                14              R$/l                2.027
# 3                                12              R$/l                2.154
# 4                               114              R$/l                2.032
# ...                             ...               ...                  ...
# 25624                            44              R$/l                4.332
# 25625                            40              R$/l                4.447
# 25626                            30              R$/l                4.503
# 25627                            12              R$/l                4.582
# 25628                            18              R$/l                4.352
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                      0.073                 1.850                 2.050
# 1                      0.171                 1.590                 2.372
# 2                      0.133                 1.750                 2.200
# 3                      0.101                 2.050                 2.250
# 4                      0.152                 1.740                 2.372
# ...                      ...                   ...                   ...
# 25624                  0.274                 3.990                 4.990
# 25625                  0.265                 3.950                 5.050
# 25626                  0.157                 4.250                 4.799
# 25627                  0.056                 4.510                 4.690
# 25628                  0.156                 4.199                 4.699
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                    0.313                     0.036                    1.691
# 1                    0.302                     0.085                    1.709
# 2                    0.482                     0.066                    1.545
# 3                    0.463                     0.047                    1.691
# 4                    0.313                     0.075                    1.719
# ...                    ...                       ...                      ...
# 25624             -99999.0                     0.063                 -99999.0
# 25625             -99999.0                     0.060                 -99999.0
# 25626             -99999.0                     0.035                 -99999.0
# 25627             -99999.0                     0.012                 -99999.0
# 25628             -99999.0                     0.036                 -99999.0
#
#       DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                          0.194                    1.2982
# 1                          0.194                    0.9826
# 2                          0.144                    1.3805
# 3                          0.194                    1.2982
# 4                          0.164                    1.0832
# ...                          ...                       ...
# 25624                   -99999.0                  -99999.0
# 25625                   -99999.0                  -99999.0
# 25626                   -99999.0                  -99999.0
# 25627                   -99999.0                  -99999.0
# 25628                   -99999.0                  -99999.0
#
#       PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                        1.8891                         0.115
# 1                        2.0852                         0.114
# 2                        1.8446                         0.093
# 3                         1.889                         0.115
# 4                        1.9841                         0.095
# ...                         ...                           ...
# 25624                  -99999.0                      -99999.0
# 25625                  -99999.0                      -99999.0
# 25626                  -99999.0                      -99999.0
# 25627                  -99999.0                      -99999.0
# 25628                  -99999.0                      -99999.0
#
# [25629 rows x 17 columns]

# %% [markdown]
# Alternativamente, poderíamos usar o método `query` para fazermos tal seleção. Porém, isso não é possível especificamente para esse caso, pois o rótulo da coluna 'PREÇO MÉDIO REVENDA' possui caracteres inválidos para o método (cedilha, acentos)

# %%
# Não funciona
# data.query('ESTADO=="RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')

# %% [markdown]
# **Aprofundando mais ainda**
#
# A primeira comparação `(data['ESTADO'] == 'RIO DE JANEIRO')` checa, linha a linha (amostra a amostra) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# A segunda comparação `(data['PREÇO MÉDIO REVENDA'] > 2)` checa, linha a linha (amostra a amostra) do DataFrame, quais são os registro cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de **TODOS os estados**. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.

# %% [markdown]
# Alguns podem argumentar que tal abordagem é **ineficiente**, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame. <br/>
# O Pandas _tenta otimizar_ isso ao máximo por de trás dos panos. Mas, de fato, de tivermos um dataset **muito grande** (centenas de milhares de linhas), tal abordagem se tornará _lenta_.

# %% [markdown]
# Assim, poderíamos fazer filtragem com múltiplos condicionais em partes:

# %%
select_1 = data['REGIÃO'] == 'NORTE'
postos_rj = data[select_1]
postos_rj
# Out:
#        DATA INICIAL  DATA FINAL REGIÃO           PRODUTO  \
# 13       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 14       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 15       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 16       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# 17       2004-05-09  2004-05-15  NORTE  ETANOL HIDRATADO
# ...             ...         ...    ...               ...
# 120799   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120809   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120817   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120818   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120822   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 13                                33              R$/l                1.805
# 14                                15              R$/l                1.785
# 15                                53              R$/l                1.578
# 16                               104              R$/l                1.914
# 17                                97              R$/l                1.545
# ...                              ...               ...                  ...
# 120799                            44              R$/l                4.332
# 120809                            40              R$/l                4.447
# 120817                            30              R$/l                4.503
# 120818                            12              R$/l                4.582
# 120822                            18              R$/l                4.352
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 13                      0.134                 1.500                 1.980
# 14                      0.035                 1.740                 1.850
# 15                      0.123                 1.280                 1.850
# 16                      0.246                 1.270                 2.400
# 17                      0.141                 1.250                 1.990
# ...                       ...                   ...                   ...
# 120799                  0.274                 3.990                 4.990
# 120809                  0.265                 3.950                 5.050
# 120817                  0.157                 4.250                 4.799
# 120818                  0.056                 4.510                 4.690
# 120822                  0.156                 4.199                 4.699
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 13                    0.689                     0.074
# 14                    0.412                     0.020
# 15                    0.441                     0.078
# 16                    0.536                     0.129
# 17                    0.533                     0.091
# ...                     ...                       ...
# 120799             -99999.0                     0.063
# 120809             -99999.0                     0.060
# 120817             -99999.0                     0.035
# 120818             -99999.0                     0.012
# 120822             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 13                        1.116                      0.171
# 14                        1.373                      0.167
# 15                        1.137                      0.068
# 16                        1.378                      0.237
# 17                        1.012                      0.149
# ...                         ...                        ...
# 120799                 -99999.0                   -99999.0
# 120809                 -99999.0                   -99999.0
# 120817                 -99999.0                   -99999.0
# 120818                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 13                         0.767                    1.2992
# 14                        0.8339                    1.4912
# 15                        0.9515                    1.2109
# 16                        0.7564                    1.8908
# 17                          0.52                    1.3306
# ...                          ...                       ...
# 120799                  -99999.0                  -99999.0
# 120809                  -99999.0                  -99999.0
# 120817                  -99999.0                  -99999.0
# 120818                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 13                             0.153
# 14                             0.122
# 15                              0.06
# 16                             0.172
# 17                             0.147
# ...                              ...
# 120799                      -99999.0
# 120809                      -99999.0
# 120817                      -99999.0
# 120818                      -99999.0
# 120822                      -99999.0
#
# [27989 rows x 17 columns]

# %%
select_2 = postos_rj['PREÇO MÉDIO REVENDA'] > 2
postos_rj[select_2]
# Out:
#        DATA INICIAL  DATA FINAL REGIÃO           PRODUTO  \
# 770      2004-11-21  2004-11-27  NORTE  ETANOL HIDRATADO
# 772      2004-11-21  2004-11-27  NORTE  ETANOL HIDRATADO
# 774      2004-11-21  2004-11-27  NORTE  ETANOL HIDRATADO
# 797      2004-11-28  2004-12-04  NORTE  ETANOL HIDRATADO
# 799      2004-11-28  2004-12-04  NORTE  ETANOL HIDRATADO
# ...             ...         ...    ...               ...
# 120799   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120809   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120817   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120818   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
# 120822   2021-04-25  2021-05-01  NORTE   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 770                               11              R$/l                2.004
# 772                               98              R$/l                2.011
# 774                               14              R$/l                2.027
# 797                               12              R$/l                2.154
# 799                              114              R$/l                2.032
# ...                              ...               ...                  ...
# 120799                            44              R$/l                4.332
# 120809                            40              R$/l                4.447
# 120817                            30              R$/l                4.503
# 120818                            12              R$/l                4.582
# 120822                            18              R$/l                4.352
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 770                     0.073                 1.850                 2.050
# 772                     0.171                 1.590                 2.372
# 774                     0.133                 1.750                 2.200
# 797                     0.101                 2.050                 2.250
# 799                     0.152                 1.740                 2.372
# ...                       ...                   ...                   ...
# 120799                  0.274                 3.990                 4.990
# 120809                  0.265                 3.950                 5.050
# 120817                  0.157                 4.250                 4.799
# 120818                  0.056                 4.510                 4.690
# 120822                  0.156                 4.199                 4.699
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 770                   0.313                     0.036
# 772                   0.302                     0.085
# 774                   0.482                     0.066
# 797                   0.463                     0.047
# 799                   0.313                     0.075
# ...                     ...                       ...
# 120799             -99999.0                     0.063
# 120809             -99999.0                     0.060
# 120817             -99999.0                     0.035
# 120818             -99999.0                     0.012
# 120822             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 770                       1.691                      0.194
# 772                       1.709                      0.194
# 774                       1.545                      0.144
# 797                       1.691                      0.194
# 799                       1.719                      0.164
# ...                         ...                        ...
# 120799                 -99999.0                   -99999.0
# 120809                 -99999.0                   -99999.0
# 120817                 -99999.0                   -99999.0
# 120818                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 770                       1.2982                    1.8891
# 772                       0.9826                    2.0852
# 774                       1.3805                    1.8446
# 797                       1.2982                     1.889
# 799                       1.0832                    1.9841
# ...                          ...                       ...
# 120799                  -99999.0                  -99999.0
# 120809                  -99999.0                  -99999.0
# 120817                  -99999.0                  -99999.0
# 120818                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 770                            0.115
# 772                            0.114
# 774                            0.093
# 797                            0.115
# 799                            0.095
# ...                              ...
# 120799                      -99999.0
# 120809                      -99999.0
# 120817                      -99999.0
# 120818                      -99999.0
# 120822                      -99999.0
#
# [25629 rows x 17 columns]

# %% [markdown]
# #### **Selecionando registros**

# %% [markdown]
# Podemos fazer a solução do "jeito mais lento", percorrendo o DataFrame inteiro _múltiplas vezes_:

# %%
selecao = ((data['REGIÃO'] == 'NORTE') | (data['REGIÃO'] == 'NORDESTE')) & (data['PREÇO MÉDIO REVENDA'] > 2) & (data['PRODUTO'] == 'ETANOL HIDRATADO')

# %%
postos_rj_sp = data[selecao]

# %%
postos_rj_sp
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO           PRODUTO  \
# 770      2004-11-21  2004-11-27     NORTE  ETANOL HIDRATADO
# 772      2004-11-21  2004-11-27     NORTE  ETANOL HIDRATADO
# 774      2004-11-21  2004-11-27     NORTE  ETANOL HIDRATADO
# 797      2004-11-28  2004-12-04     NORTE  ETANOL HIDRATADO
# 799      2004-11-28  2004-12-04     NORTE  ETANOL HIDRATADO
# ...             ...         ...       ...               ...
# 120664   2021-04-25  2021-05-01  NORDESTE  ETANOL HIDRATADO
# 120666   2021-04-25  2021-05-01     NORTE  ETANOL HIDRATADO
# 120667   2021-04-25  2021-05-01     NORTE  ETANOL HIDRATADO
# 120670   2021-04-25  2021-05-01  NORDESTE  ETANOL HIDRATADO
# 120671   2021-04-25  2021-05-01     NORTE  ETANOL HIDRATADO
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 770                               11              R$/l                2.004
# 772                               98              R$/l                2.011
# 774                               14              R$/l                2.027
# 797                               12              R$/l                2.154
# 799                              114              R$/l                2.032
# ...                              ...               ...                  ...
# 120664                            27              R$/l                4.634
# 120666                            14              R$/l                4.647
# 120667                             2              R$/l                4.530
# 120670                            26              R$/l                4.509
# 120671                            16              R$/l                4.757
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 770                     0.073                 1.850                 2.050
# 772                     0.171                 1.590                 2.372
# 774                     0.133                 1.750                 2.200
# 797                     0.101                 2.050                 2.250
# 799                     0.152                 1.740                 2.372
# ...                       ...                   ...                   ...
# 120664                  0.140                 4.320                 4.890
# 120666                  0.314                 4.370                 5.190
# 120667                  0.085                 4.470                 4.590
# 120670                  0.050                 4.449                 4.649
# 120671                  0.153                 4.570                 4.999
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 770                   0.313                     0.036
# 772                   0.302                     0.085
# 774                   0.482                     0.066
# 797                   0.463                     0.047
# 799                   0.313                     0.075
# ...                     ...                       ...
# 120664             -99999.0                     0.030
# 120666             -99999.0                     0.068
# 120667             -99999.0                     0.019
# 120670             -99999.0                     0.011
# 120671             -99999.0                     0.032
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 770                       1.691                      0.194
# 772                       1.709                      0.194
# 774                       1.545                      0.144
# 797                       1.691                      0.194
# 799                       1.719                      0.164
# ...                         ...                        ...
# 120664                 -99999.0                   -99999.0
# 120666                 -99999.0                   -99999.0
# 120667                 -99999.0                   -99999.0
# 120670                 -99999.0                   -99999.0
# 120671                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 770                       1.2982                    1.8891
# 772                       0.9826                    2.0852
# 774                       1.3805                    1.8446
# 797                       1.2982                     1.889
# 799                       1.0832                    1.9841
# ...                          ...                       ...
# 120664                  -99999.0                  -99999.0
# 120666                  -99999.0                  -99999.0
# 120667                  -99999.0                  -99999.0
# 120670                  -99999.0                  -99999.0
# 120671                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 770                            0.115
# 772                            0.114
# 774                            0.093
# 797                            0.115
# 799                            0.095
# ...                              ...
# 120664                      -99999.0
# 120666                      -99999.0
# 120667                      -99999.0
# 120670                      -99999.0
# 120671                      -99999.0
#
# [9796 rows x 17 columns]

# %% [markdown]
# <br/>
#
# Alternativamente:

# %%
selecao = ((data['REGIÃO'] == 'NORTE') | (data['REGIÃO'] == 'NORDESTE'))

# %%
postos_sp_rj = data[selecao]

# %%
selecao_2 = (postos_sp_rj['PREÇO MÉDIO REVENDA'] > 2)
postos_sp_rj = postos_sp_rj[selecao_2]

# %%
selecao_3 = (postos_sp_rj['PRODUTO'] == 'ETANOL HIDRATADO')
postos_sp_rj = postos_sp_rj[selecao_3]

# %%
postos_sp_rj
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO           PRODUTO  \
# 770      2004-11-21  2004-11-27     NORTE  ETANOL HIDRATADO
# 772      2004-11-21  2004-11-27     NORTE  ETANOL HIDRATADO
# 774      2004-11-21  2004-11-27     NORTE  ETANOL HIDRATADO
# 797      2004-11-28  2004-12-04     NORTE  ETANOL HIDRATADO
# 799      2004-11-28  2004-12-04     NORTE  ETANOL HIDRATADO
# ...             ...         ...       ...               ...
# 120664   2021-04-25  2021-05-01  NORDESTE  ETANOL HIDRATADO
# 120666   2021-04-25  2021-05-01     NORTE  ETANOL HIDRATADO
# 120667   2021-04-25  2021-05-01     NORTE  ETANOL HIDRATADO
# 120670   2021-04-25  2021-05-01  NORDESTE  ETANOL HIDRATADO
# 120671   2021-04-25  2021-05-01     NORTE  ETANOL HIDRATADO
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 770                               11              R$/l                2.004
# 772                               98              R$/l                2.011
# 774                               14              R$/l                2.027
# 797                               12              R$/l                2.154
# 799                              114              R$/l                2.032
# ...                              ...               ...                  ...
# 120664                            27              R$/l                4.634
# 120666                            14              R$/l                4.647
# 120667                             2              R$/l                4.530
# 120670                            26              R$/l                4.509
# 120671                            16              R$/l                4.757
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 770                     0.073                 1.850                 2.050
# 772                     0.171                 1.590                 2.372
# 774                     0.133                 1.750                 2.200
# 797                     0.101                 2.050                 2.250
# 799                     0.152                 1.740                 2.372
# ...                       ...                   ...                   ...
# 120664                  0.140                 4.320                 4.890
# 120666                  0.314                 4.370                 5.190
# 120667                  0.085                 4.470                 4.590
# 120670                  0.050                 4.449                 4.649
# 120671                  0.153                 4.570                 4.999
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 770                   0.313                     0.036
# 772                   0.302                     0.085
# 774                   0.482                     0.066
# 797                   0.463                     0.047
# 799                   0.313                     0.075
# ...                     ...                       ...
# 120664             -99999.0                     0.030
# 120666             -99999.0                     0.068
# 120667             -99999.0                     0.019
# 120670             -99999.0                     0.011
# 120671             -99999.0                     0.032
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 770                       1.691                      0.194
# 772                       1.709                      0.194
# 774                       1.545                      0.144
# 797                       1.691                      0.194
# 799                       1.719                      0.164
# ...                         ...                        ...
# 120664                 -99999.0                   -99999.0
# 120666                 -99999.0                   -99999.0
# 120667                 -99999.0                   -99999.0
# 120670                 -99999.0                   -99999.0
# 120671                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 770                       1.2982                    1.8891
# 772                       0.9826                    2.0852
# 774                       1.3805                    1.8446
# 797                       1.2982                     1.889
# 799                       1.0832                    1.9841
# ...                          ...                       ...
# 120664                  -99999.0                  -99999.0
# 120666                  -99999.0                  -99999.0
# 120667                  -99999.0                  -99999.0
# 120670                  -99999.0                  -99999.0
# 120671                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 770                            0.115
# 772                            0.114
# 774                            0.093
# 797                            0.115
# 799                            0.095
# ...                              ...
# 120664                      -99999.0
# 120666                      -99999.0
# 120667                      -99999.0
# 120670                      -99999.0
# 120671                      -99999.0
#
# [9796 rows x 17 columns]

# %% [markdown]
# ### **Iterando com DataFrames**

# %% [markdown]
# #### For-each `DataFrame.iterrows()` (LENTO ==> apenas indicado para iterar pequenos conjunto de dados)

# %%
for index, row in data.head(10).iterrows():
    print(f'Index : {index} ==> {row["REGIÃO"]}')
# Out:
# Index : 0 ==> CENTRO OESTE
# Index : 1 ==> CENTRO OESTE
# Index : 2 ==> CENTRO OESTE
# Index : 3 ==> CENTRO OESTE
# Index : 4 ==> NORDESTE
# Index : 5 ==> NORDESTE
# Index : 6 ==> NORDESTE
# Index : 7 ==> NORDESTE
# Index : 8 ==> NORDESTE
# Index : 9 ==> NORDESTE

# %% [markdown]
# <h2>2. Preparação dos dados</h2>
# <hr/>

# %% [markdown]
# ### 2.1 Removendo amostras com valores vazios (null / nan) no dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  object
#  1   DATA FINAL                     120823 non-null  object
#  2   REGIÃO                         120823 non-null  object
#  3   PRODUTO                        120823 non-null  object
#  4   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  5   UNIDADE DE MEDIDA              120823 non-null  object
#  6   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  7   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  8   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  9   PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  10  MARGEM MÉDIA REVENDA           120823 non-null  object
#  11  COEF DE VARIAÇÃO REVENDA       120823 non-null  float64
#  12  PREÇO MÉDIO DISTRIBUIÇÃO       120823 non-null  object
#  13  DESVIO PADRÃO DISTRIBUIÇÃO     120823 non-null  object
#  14  PREÇO MÍNIMO DISTRIBUIÇÃO      120823 non-null  object
#  15  PREÇO MÁXIMO DISTRIBUIÇÃO      120823 non-null  object
#  16  COEF DE VARIAÇÃO DISTRIBUIÇÃO  120823 non-null  object
# dtypes: float64(5), int64(1), object(11)
# memory usage: 15.7+ MB

# %% [markdown]
# De um total de 106823 observações, **não há valores null** / nan para nenhum atributo. Mas, veremos que não é bem assim neste caso específico.<br/><br/>

# %% [markdown]
# ### 2.2 Conversão de tipos de atributos

# %% [markdown]
# O pandas automaticamente reconhece os tipos de dados de cada coluna. <br/>
# Porém, existem alguns atributos que estão com seus tipos errados: P. ex., "PREÇO MÉDIO DISTRIBUIÇÃO" deveria ser ```float64``` e não ```object```.<br/>
# Nestes casos, muito provavelmente algumas amostras têm um string ao invés de um número para tais atributos. <br/>
#
# Os atributos *"DATA INICIAL"* e *"DATA FINAL"* deveriam ser do tipo `datetime`.
#
# Em outros casos, alguns **atributos categóricos** são ```objects```, mas poderiam ter o tipo ```category```, que é um tipo especial do pandas. <br/>
# Este tipo é necessário para se utilizar algumas funções específicas do pandas. <br/>
# **Não** converteremos para este tipo por ora.

# %%
data_pre = data.copy()

# %% [markdown]
# #### **Datas**
# Como os atributos de data do datset já estão em um formato de data aceitável (YYYY-MM-DD), não precisamos forçar nenhuma conversão nesse sentido.

# %%
data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])

# %%
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  datetime64[ns]
#  1   DATA FINAL                     120823 non-null  datetime64[ns]
#  2   REGIÃO                         120823 non-null  object
#  3   PRODUTO                        120823 non-null  object
#  4   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  5   UNIDADE DE MEDIDA              120823 non-null  object
#  6   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  7   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  8   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  9   PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  10  MARGEM MÉDIA REVENDA           120823 non-null  object
#  11  COEF DE VARIAÇÃO REVENDA       120823 non-null  float64
#  12  PREÇO MÉDIO DISTRIBUIÇÃO       120823 non-null  object
#  13  DESVIO PADRÃO DISTRIBUIÇÃO     120823 non-null  object
#  14  PREÇO MÍNIMO DISTRIBUIÇÃO      120823 non-null  object
#  15  PREÇO MÁXIMO DISTRIBUIÇÃO      120823 non-null  object
#  16  COEF DE VARIAÇÃO DISTRIBUIÇÃO  120823 non-null  object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(9)
# memory usage: 15.7+ MB

# %% [markdown]
# #### **Dados Numéricos**

# %%
lista = ['MARGEM MÉDIA REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO',
 'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO']

# %%
for atributo in lista:
    data_pre[atributo] = pd.to_numeric(data_pre[atributo], errors='coerce')

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  datetime64[ns]
#  1   DATA FINAL                     120823 non-null  datetime64[ns]
#  2   REGIÃO                         120823 non-null  object
#  3   PRODUTO                        120823 non-null  object
#  4   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  5   UNIDADE DE MEDIDA              120823 non-null  object
#  6   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  7   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  8   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  9   PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  10  MARGEM MÉDIA REVENDA           117392 non-null  float64
#  11  COEF DE VARIAÇÃO REVENDA       120823 non-null  float64
#  12  PREÇO MÉDIO DISTRIBUIÇÃO       117423 non-null  float64
#  13  DESVIO PADRÃO DISTRIBUIÇÃO     117423 non-null  float64
#  14  PREÇO MÍNIMO DISTRIBUIÇÃO      117423 non-null  float64
#  15  PREÇO MÁXIMO DISTRIBUIÇÃO      117423 non-null  float64
#  16  COEF DE VARIAÇÃO DISTRIBUIÇÃO  117423 non-null  float64
# dtypes: datetime64[ns](2), float64(11), int64(1), object(3)
# memory usage: 15.7+ MB

# %% [markdown]
# <br/>
#
# Note que temos vários valores ***null*** agora **após a *conversão de tipos***. Vamos checá-los com mais cuidado nos dados originais e preprocessados.

# %% [markdown]
# ### 2.3 Limpeza de dados

# %%
#O atributo não possui registros null, mas irei seguir como se fosse.
eh_null = data_pre['PREÇO MÍNIMO DISTRIBUIÇÃO'].isnull()
eh_null
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 120818    False
# 120819    False
# 120820    False
# 120821    False
# 120822    False
# Name: PREÇO MÍNIMO DISTRIBUIÇÃO, Length: 120823, dtype: bool

# %%
data_pre[eh_null]
# Out:
# Empty DataFrame
# Columns: [DATA INICIAL, DATA FINAL, REGIÃO, PRODUTO, NÚMERO DE POSTOS PESQUISADOS, UNIDADE DE MEDIDA, PREÇO MÉDIO REVENDA, DESVIO PADRÃO REVENDA, PREÇO MÍNIMO REVENDA, PREÇO MÁXIMO REVENDA, MARGEM MÉDIA REVENDA, COEF DE VARIAÇÃO REVENDA, PREÇO MÉDIO DISTRIBUIÇÃO, DESVIO PADRÃO DISTRIBUIÇÃO, PREÇO MÍNIMO DISTRIBUIÇÃO, PREÇO MÁXIMO DISTRIBUIÇÃO, COEF DE VARIAÇÃO DISTRIBUIÇÃO]
# Index: []

# %% [markdown]
# <br/>
#
# Poderíamos **preencher os valores NaN com um valor padrão**. Para isso, basta usar o método `.fillna`.

# %%
data_pre_fill = data_pre.fillna(0)
data_pre_fill
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO           PRODUTO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 1        2004-05-09 2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 2        2004-05-09 2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 3        2004-05-09 2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 4        2004-05-09 2004-05-15      NORDESTE  ETANOL HIDRATADO
# ...             ...        ...           ...               ...
# 120818   2021-04-25 2021-05-01         NORTE   OLEO DIESEL S10
# 120819   2021-04-25 2021-05-01           SUL   OLEO DIESEL S10
# 120820   2021-04-25 2021-05-01       SUDESTE   OLEO DIESEL S10
# 120821   2021-04-25 2021-05-01      NORDESTE   OLEO DIESEL S10
# 120822   2021-04-25 2021-05-01         NORTE   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                                127              R$/l                1.288
# 1                                387              R$/l                1.162
# 2                                192              R$/l                1.389
# 3                                162              R$/l                1.262
# 4                                103              R$/l                1.181
# ...                              ...               ...                  ...
# 120818                            12              R$/l                4.582
# 120819                           100              R$/l                4.141
# 120820                           886              R$/l                4.246
# 120821                            33              R$/l                4.464
# 120822                            18              R$/l                4.352
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                       0.016                 1.190                 1.350
# 1                       0.114                 0.890                 1.449
# 2                       0.097                 1.180                 1.760
# 3                       0.070                 1.090                 1.509
# 4                       0.078                 1.050                 1.400
# ...                       ...                   ...                   ...
# 120818                  0.056                 4.510                 4.690
# 120819                  0.187                 3.838                 4.739
# 120820                  0.216                 3.769                 5.199
# 120821                  0.205                 4.190                 4.699
# 120822                  0.156                 4.199                 4.699
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                     0.463                     0.012
# 1                     0.399                     0.098
# 2                     0.419                     0.070
# 3                     0.432                     0.055
# 4                      0.24                     0.066
# ...                     ...                       ...
# 120818             -99999.0                     0.012
# 120819             -99999.0                     0.045
# 120820             -99999.0                     0.051
# 120821             -99999.0                     0.046
# 120822             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 120818                 -99999.0                   -99999.0
# 120819                 -99999.0                   -99999.0
# 120820                 -99999.0                   -99999.0
# 120821                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 120818                  -99999.0                  -99999.0
# 120819                  -99999.0                  -99999.0
# 120820                  -99999.0                  -99999.0
# 120821                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                              0.133
# 1                              0.115
# 2                              0.098
# 3                              0.143
# 4                              0.082
# ...                              ...
# 120818                      -99999.0
# 120819                      -99999.0
# 120820                      -99999.0
# 120821                      -99999.0
# 120822                      -99999.0
#
# [120823 rows x 17 columns]

# %%
data_pre_fill = data_pre.fillna(value = {
    'DESVIO PADRÃO REVENDA' : 10,
    'PREÇO MÉDIO REVENDA' : 20
})

# %% [markdown]
# <br/>
#
# Por mais que a função `fillna` seja interessante e útil em muitos casos, no problema em questão estamos interessados em analisar precisamente, p. ex., o **'PREÇO MÉDIO DISTRIBUIÇÃO'**.<br/>
# A fim de não termos valores _sintéticos_ gerados pelo `fillna`, que possam atrapalhar nossa análise, iremos **remover (drop) todas as amostras que possuem qualquer valor NaN** para quaisquer atributos/colunas. <br/>
#
# Para isso, basta utilizarmos o método `dropna`.

# %%
data_pre.dropna(inplace=True)
data = data_pre

# %%
data.to_csv(r'C:\Users\Armando\Downloads\archive\2004-2021.tsv')

# %% [markdown]
# Essas são apenas algumas das possíveis _técnicas de limpeza de dados_. Outras estratégias, p. ex., **confiam na detecção de outliers**, que não veremos neste curso.

# %% [markdown]
# <h2>3. Estatísticas Descritivas</h2>
# <hr/>

# %% [markdown]
# O Pandas fornecem algumas funções/métodos ue computam certas estatísticas descritivas.

# %% [markdown]
# `describe`: exibe várias **estatísticas descritivas** para os _atributos_ de um dataframe ou para uma _Series_.

# %%
data.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 117392.000000        117392.000000
# mean                     226.632190            11.415039
# std                      392.042029            19.149383
# min                        1.000000             0.766000
# 25%                       42.000000             2.159000
# 50%                      102.000000             2.915000
# 75%                      229.250000             4.023000
# max                     4167.000000           107.500000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          117392.000000         117392.000000         117392.000000
# mean                0.680834              9.922806             13.184631
# std                 1.402620             16.418908             22.465797
# min                 0.000000              0.590000              0.999000
# 25%                 0.076000              1.990000              2.440000
# 50%                 0.121000              2.699000              3.240000
# 75%                 0.203000              3.780000              4.580000
# max                10.748000            100.000000            120.000000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         117392.000000             117392.000000
# mean           -4697.376395                  0.045586
# std            21163.482182                  0.024240
# min           -99999.000000                  0.000000
# 25%                0.272000                  0.030000
# 50%                0.381000                  0.042000
# 75%                0.554000                  0.058000
# max               36.847000                  0.262000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             117392.000000               117392.000000
# mean               -4683.425711                -4691.371824
# std                21148.461919                21146.694241
# min               -99999.000000               -99999.000000
# 25%                    1.757000                    0.044000
# 50%                    2.359000                    0.076000
# 75%                    3.364000                    0.148000
# max                   83.137000                   18.385000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              117392.000000              117392.000000
# mean                -4684.543450               -4682.203033
# std                 21148.212724               21148.734887
# min                -99999.000000              -99999.000000
# 25%                     1.638000                   1.900275
# 50%                     2.238300                   2.537800
# 75%                     3.199650                   3.576200
# max                    83.000000                  94.500000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# count                  117392.000000
# mean                    -4691.881144
# std                     21146.581196
# min                    -99999.000000
# 25%                         0.019000
# 50%                         0.029000
# 75%                         0.058000
# max                         0.780000

# %% [markdown]
# <br/>
#
# Como o resultado do `describe` de um _dataframe_ é outro _dataframe_, podemos filtrar apenas algumas colunas.

# %%
data['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    117392.000000
# mean         11.415039
# std          19.149383
# min           0.766000
# 25%           2.159000
# 50%           2.915000
# 75%           4.023000
# max         107.500000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
data.describe()['PREÇO MÉDIO REVENDA']
# Out:
# count    117392.000000
# mean         11.415039
# std          19.149383
# min           0.766000
# 25%           2.159000
# 50%           2.915000
# 75%           4.023000
# max         107.500000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %% [markdown]
# **Acessando apenas algumas estatísticas**

# %%
stats = data.describe()
stats
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 117392.000000        117392.000000
# mean                     226.632190            11.415039
# std                      392.042029            19.149383
# min                        1.000000             0.766000
# 25%                       42.000000             2.159000
# 50%                      102.000000             2.915000
# 75%                      229.250000             4.023000
# max                     4167.000000           107.500000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          117392.000000         117392.000000         117392.000000
# mean                0.680834              9.922806             13.184631
# std                 1.402620             16.418908             22.465797
# min                 0.000000              0.590000              0.999000
# 25%                 0.076000              1.990000              2.440000
# 50%                 0.121000              2.699000              3.240000
# 75%                 0.203000              3.780000              4.580000
# max                10.748000            100.000000            120.000000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         117392.000000             117392.000000
# mean           -4697.376395                  0.045586
# std            21163.482182                  0.024240
# min           -99999.000000                  0.000000
# 25%                0.272000                  0.030000
# 50%                0.381000                  0.042000
# 75%                0.554000                  0.058000
# max               36.847000                  0.262000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             117392.000000               117392.000000
# mean               -4683.425711                -4691.371824
# std                21148.461919                21146.694241
# min               -99999.000000               -99999.000000
# 25%                    1.757000                    0.044000
# 50%                    2.359000                    0.076000
# 75%                    3.364000                    0.148000
# max                   83.137000                   18.385000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              117392.000000              117392.000000
# mean                -4684.543450               -4682.203033
# std                 21148.212724               21148.734887
# min                -99999.000000              -99999.000000
# 25%                     1.638000                   1.900275
# 50%                     2.238300                   2.537800
# 75%                     3.199650                   3.576200
# max                    83.000000                  94.500000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# count                  117392.000000
# mean                    -4691.881144
# std                     21146.581196
# min                    -99999.000000
# 25%                         0.019000
# 50%                         0.029000
# 75%                         0.058000
# max                         0.780000

# %%
stats.loc[['min', 'max', 'mean']]
# Out:
#       NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# min                        1.00000             0.766000
# max                     4167.00000           107.500000
# mean                     226.63219            11.415039
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# min                0.000000              0.590000              0.999000
# max               10.748000            100.000000            120.000000
# mean               0.680834              9.922806             13.184631
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# min          -99999.000000                  0.000000
# max              36.847000                  0.262000
# mean          -4697.376395                  0.045586
#
#       PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# min              -99999.000000               -99999.000000
# max                  83.137000                   18.385000
# mean              -4683.425711                -4691.371824
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# min                -99999.00000              -99999.000000
# max                    83.00000                  94.500000
# mean                -4684.54345               -4682.203033
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO
# min                   -99999.000000
# max                        0.780000
# mean                   -4691.881144

# %%
stats['NÚMERO DE POSTOS PESQUISADOS']
# Out:
# count    117392.000000
# mean        226.632190
# std         392.042029
# min           1.000000
# 25%          42.000000
# 50%         102.000000
# 75%         229.250000
# max        4167.000000
# Name: NÚMERO DE POSTOS PESQUISADOS, dtype: float64

# %%
stats.loc[['min', 'max', 'mean'], 'NÚMERO DE POSTOS PESQUISADOS']
# Out:
# min        1.00000
# max     4167.00000
# mean     226.63219
# Name: NÚMERO DE POSTOS PESQUISADOS, dtype: float64

# %% [markdown]
# <br/>
#
# `mean`, `std`, `min`, etc: cada uma das estatísticas do `describe` podem ser computadas individualmente:

# %% [markdown]
# #### Qual é o menor preço mínimo de revenda?

# %%
data['PREÇO MÍNIMO REVENDA'].min()

# %% [markdown]
# #### Qual é a média e desvio padrão dos preços mínimos de revenda?

# %%
media = data['PREÇO MÍNIMO REVENDA'].mean()
desvio_padrao = data['PREÇO MÍNIMO REVENDA'].std()

print(f'A média dos preços mínimos de revenda é: {media:.2f}\nE seu desvio padrão é: {desvio_padrao:.2f}')
# Out:
# A média dos preços mínimos de revenda é: 9.92
# E seu desvio padrão é: 16.42

# %% [markdown]
# #### Quais são as regiões consideradas?

# %%
data['REGIÃO']
# Out:
# 0         CENTRO OESTE
# 1         CENTRO OESTE
# 2         CENTRO OESTE
# 3         CENTRO OESTE
# 4             NORDESTE
#               ...
# 120818           NORTE
# 120819             SUL
# 120820         SUDESTE
# 120821        NORDESTE
# 120822           NORTE
# Name: REGIÃO, Length: 117392, dtype: object

# %%
data['REGIÃO'].unique()
# Out:
# array(['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'],
#       dtype=object)

# %% [markdown]
# #### Quantos registros (aferições) cada região possui?

# %% [markdown]
# `.value_counts()`:  Conta a frequência dos valores de uma dada variável (de preferência, _categórica_).

# %%
data['REGIÃO'].value_counts()
# Out:
# NORDESTE        40590
# NORTE           27287
# SUDESTE         18967
# CENTRO OESTE    16565
# SUL             13983
# Name: REGIÃO, dtype: int64

# %%
df_registros_regiao = data['REGIÃO'].value_counts().to_frame()

# %%
df_registros_regiao.rename(columns={'REGIÃO': 'REGISTROS'}, inplace=True)

# %%
df_registros_regiao
# Out:
#               REGISTROS
# NORDESTE          40590
# NORTE             27287
# SUDESTE           18967
# CENTRO OESTE      16565
# SUL               13983

# %% [markdown]
# <h2>4. Executando funções para cada item de um DataFrame ou Series</h2>
# <hr/>

# %% [markdown]
# Uma alternativa ao `for-loop` que vimos anteriormente e que é _lento_, é usarmos _funções próprias do pandas_ que **aplicam/mapeiam uma dada função a todos os elementos de um DataFrame ou Series**, retornando novos elementos "transformados".

# %% [markdown]
# <img src='./imagens/apply_map_applymap.png' width=300/>
#
#
# Fonte: https://towardsdatascience.com/introduction-to-pandas-apply-applymap-and-map-5d3e044e93ff

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4], 
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]}, 
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# `apply()`: usado para aplicar uma função ao longo de um eixo de um DataFrame ou em valores de uma Series.

# %% [markdown]
# <img src='./imagens/pandas_axis.jpg' width=500/>
#
# Fonte: https://www.allthesnippets.com/browse/pandas/df_axis.html

# %%
def nossa_soma(linha):
    return linha.sum()

# %%
df['SOMA(A,B,C)'] = df.apply(nossa_soma, axis =1)

# %%
df.dropna(inplace = True)

# %% [markdown]
# <img src='./imagens/apply_axis_1.png' width=250/>

# %%
df.loc['TOTAL COLUNA'] = df.apply(nossa_soma, axis = 0)
df
# Out:
#                  A      B       C  SOMA(A,B,C)
# Linha 1        1.0   10.0   100.0        222.0
# Linha 2        2.0   20.0   200.0        444.0
# Linha 3        3.0   30.0   300.0        666.0
# Linha 4        4.0   40.0   400.0        888.0
# TOTAL COLUNA  30.0  300.0  3000.0       6660.0

# %% [markdown]
# <img src='./imagens/apply_axis_0.png' width=250/>

# %% [markdown]
# ##### Usando `lambda` functions

# %%
df['MÉDIA(A, B, C)'] = df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis = 1)

# %%
df
# Out:
#                  A      B       C  SOMA(A,B,C)  MÉDIA(A, B, C)
# Linha 1        1.0   10.0   100.0        222.0            37.0
# Linha 2        2.0   20.0   200.0        444.0            74.0
# Linha 3        3.0   30.0   300.0        666.0           111.0
# Linha 4        4.0   40.0   400.0        888.0           148.0
# TOTAL COLUNA  30.0  300.0  3000.0       6660.0          1110.0

# %% [markdown]
# <img src='./imagens/apply_axis_1_mean.png' width=350/>

# %%
df.loc['MÉDIA(COLUNA)'] = df.loc[['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4']].apply(lambda series: series.mean(), axis =0)
df
# Out:
#                   A      B       C  SOMA(A,B,C)  MÉDIA(A, B, C)
# Linha 1         1.0   10.0   100.0        222.0            37.0
# Linha 2         2.0   20.0   200.0        444.0            74.0
# Linha 3         3.0   30.0   300.0        666.0           111.0
# Linha 4         4.0   40.0   400.0        888.0           148.0
# TOTAL COLUNA   30.0  300.0  3000.0       6660.0          1110.0
# MÉDIA(COLUNA)   2.5   25.0   250.0        555.0            92.5

# %% [markdown]
# <h2>5. Agrupamento</h2>
# <hr/>

# %% [markdown]
# `groupby`: Usado para criar **grupo de elementos** (e.x., baseado nos valores de um atributo). <br/>
# **Funções** podem então ser aplicadas para os _elementos de cada grupo_, de modo que os **resultados de cada grupo são combinados**.

# %%
grupos_regiao = data.groupby('REGIÃO')

# %%
grupos_regiao.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14, 15, 16, 17, 18, 19, 40, 41, 42, 43, 44, 45, 46, 67, 68, 69, 70, 71, 72, 73, 94, 95, 96, 97, 98, 99, 100, 121, 122, 123, 124, 125, 126, 127, 148, 149, 150, 151, 152, 153, 154, 175, 176, 177, 178, 179, 180, 181, 202, 203, 204, 205, 206, 207, 208, 229, 230, 231, 232, 233, 234, 235, 256, 257, 258, 259, 260, 261, 262, 283, 284, 285, 286, 287, 288, 289, 310, 311, 312, 313, 314, 315, 316, 337, 338, 339, 340, 341, 342, 343, 364, 365, 366, 367, 368, 369, 370, 391, 392, ...], 'SUDESTE': [20, 21, 22, 23, 47, 48, 49, 50, 74, 75, 76, 77, 101, 102, 103, 104, 128, 129, 130, 131, 155, 156, 157, 158, 182, 183, 184, 185, 209, 210, 211, 212, 236, 237, 238, 239, 263, 264, 265, 266, 290, 291, 292, 293, 317, 318, 319, 320, 344, 345, 346, 347, 371, 372, 373, 374, 398, 399, 400, 401, 425, 426, 427, 428, 452, 453, 454, 455, 479, 480, 481, 482, 506, 507, 508, 509, 533, 534, 535, 536, 560, 561, 562, 563, 587, 588, 589, 590, 614, 615, 616, 617, 641, 642, 643, 644, 668, 669, 670, 671, ...], 'SUL': [24, 25, 26, 51, 52, 53, 78, 79, 80, 105, 106, 107, 132, 133, 134, 159, 160, 161, 186, 187, 188, 213, 214, 215, 240, 241, 242, 267, 268, 269, 294, 295, 296, 321, 322, 323, 348, 349, 350, 375, 376, 377, 402, 403, 404, 429, 430, 431, 456, 457, 458, 483, 484, 485, 510, 511, 512, 537, 538, 539, 564, 565, 566, 591, 592, 593, 618, 619, 620, 645, 646, 647, 672, 673, 674, 699, 700, 701, 726, 727, 728, 753, 754, 755, 780, 781, 782, 807, 808, 809, 834, 835, 836, 861, 862, 863, 888, 889, 890, 915, ...]}

# %%
grupos_regiao.get_group('CENTRO OESTE')
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO           PRODUTO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 1        2004-05-09 2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 2        2004-05-09 2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 3        2004-05-09 2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 27       2004-05-16 2004-05-22  CENTRO OESTE  ETANOL HIDRATADO
# ...             ...        ...           ...               ...
# 120780   2021-04-25 2021-05-01  CENTRO OESTE       OLEO DIESEL
# 120802   2021-04-25 2021-05-01  CENTRO OESTE   OLEO DIESEL S10
# 120804   2021-04-25 2021-05-01  CENTRO OESTE   OLEO DIESEL S10
# 120806   2021-04-25 2021-05-01  CENTRO OESTE   OLEO DIESEL S10
# 120807   2021-04-25 2021-05-01  CENTRO OESTE   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                                127              R$/l                1.288
# 1                                387              R$/l                1.162
# 2                                192              R$/l                1.389
# 3                                162              R$/l                1.262
# 27                               144              R$/l                1.271
# ...                              ...               ...                  ...
# 120780                            30              R$/l                4.203
# 120802                            35              R$/l                4.318
# 120804                            66              R$/l                4.402
# 120806                           101              R$/l                4.594
# 120807                            44              R$/l                4.232
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                       0.016                 1.190                 1.350
# 1                       0.114                 0.890                 1.449
# 2                       0.097                 1.180                 1.760
# 3                       0.070                 1.090                 1.509
# 27                      0.039                 1.060                 1.300
# ...                       ...                   ...                   ...
# 120780                  0.174                 3.889                 4.649
# 120802                  0.141                 4.058                 4.599
# 120804                  0.150                 4.140                 4.799
# 120806                  0.139                 4.299                 4.899
# 120807                  0.151                 3.990                 4.699
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 27                     0.448                     0.031
# ...                      ...                       ...
# 120780            -99999.000                     0.041
# 120802            -99999.000                     0.033
# 120804            -99999.000                     0.034
# 120806            -99999.000                     0.030
# 120807            -99999.000                     0.036
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 27                         0.823                       0.111
# ...                          ...                         ...
# 120780                -99999.000                  -99999.000
# 120802                -99999.000                  -99999.000
# 120804                -99999.000                  -99999.000
# 120806                -99999.000                  -99999.000
# 120807                -99999.000                  -99999.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 27                         0.4094                    1.19310
# ...                           ...                        ...
# 120780                -99999.0000               -99999.00000
# 120802                -99999.0000               -99999.00000
# 120804                -99999.0000               -99999.00000
# 120806                -99999.0000               -99999.00000
# 120807                -99999.0000               -99999.00000
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                               0.133
# 1                               0.115
# 2                               0.098
# 3                               0.143
# 27                              0.135
# ...                               ...
# 120780                     -99999.000
# 120802                     -99999.000
# 120804                     -99999.000
# 120806                     -99999.000
# 120807                     -99999.000
#
# [16565 rows x 17 columns]

# %%
grupos_regiao.describe()
# Out:
#              NÚMERO DE POSTOS PESQUISADOS                                      \
#                                     count        mean         std  min    25%
# REGIÃO
# CENTRO OESTE                      16565.0  137.275521  103.448516  1.0   76.0
# NORDESTE                          40590.0  118.363439  110.578621  1.0   38.0
# NORTE                             27287.0   64.003921   51.745055  1.0   28.0
# SUDESTE                           18967.0  684.316655  763.338730  1.0  146.0
# SUL                               13983.0  343.313738  231.843167  1.0  150.0
#
#                                    PREÇO MÉDIO REVENDA             ...  \
#                 50%    75%     max               count       mean  ...
# REGIÃO                                                             ...
# CENTRO OESTE  118.0  176.0   766.0             16565.0  12.873181  ...
# NORDESTE       84.0  153.0   625.0             40590.0  10.202962  ...
# NORTE          50.0   89.0   383.0             27287.0  13.397427  ...
# SUDESTE       384.0  984.0  4167.0             18967.0  10.338534  ...
# SUL           355.0  542.5  1416.0             13983.0  10.797774  ...
#
#              PREÇO MÁXIMO DISTRIBUIÇÃO        COEF DE VARIAÇÃO DISTRIBUIÇÃO  \
#                                    75%    max                         count
# REGIÃO
# CENTRO OESTE                   3.65000  94.50                       16565.0
# NORDESTE                       3.43080  89.90                       40590.0
# NORTE                          3.88490  88.00                       27287.0
# SUDESTE                        3.53805  76.05                       18967.0
# SUL                            3.47025  74.00                       13983.0
#
#
#                      mean           std      min    25%    50%    75%    max
# REGIÃO
# CENTRO OESTE -4811.263454  21401.044211 -99999.0  0.017  0.027  0.049  0.419
# NORDESTE     -4614.345790  20979.826818 -99999.0  0.018  0.030  0.061  0.608
# NORTE        -4760.427972  21293.104215 -99999.0  0.017  0.027  0.043  0.368
# SUDESTE      -4502.455107  20736.375552 -99999.0  0.023  0.035  0.079  0.780
# SUL          -4898.703597  21584.874201 -99999.0  0.023  0.034  0.082  0.435
#
# [5 rows x 96 columns]

# %%
grupos_regiao.mean()
# Out:
# C:\Users\Armando\AppData\Local\Temp\ipykernel_3100\1911814995.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grupos_regiao.mean()
#               NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# REGIÃO
# CENTRO OESTE                    137.275521            12.873181
# NORDESTE                        118.363439            10.202962
# NORTE                            64.003921            13.397427
# SUDESTE                         684.316655            10.338534
# SUL                             343.313738            10.797774
#
#               DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# REGIÃO
# CENTRO OESTE               0.738618             11.086225
# NORDESTE                   0.576010              8.982218
# NORTE                      0.741401             12.149052
# SUDESTE                    0.710891              8.427834
# SUL                        0.757697              8.958349
#
#               PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# REGIÃO
# CENTRO OESTE             14.732801          -4808.871317
# NORDESTE                 11.518819          -4627.099422
# NORTE                    15.257880          -4758.258064
# SUDESTE                  12.526857          -4516.020832
# SUL                      13.032530          -4896.484015
#
#               COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                  0.041948              -4801.630072
# NORDESTE                      0.041058              -4606.907509
# NORTE                         0.047056              -4750.097756
# SUDESTE                       0.054994              -4495.080899
# SUL                           0.047411              -4890.882948
#
#               DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                -4810.611556               -4802.940678
# NORDESTE                    -4613.883482               -4607.830545
# NORTE                       -4760.014513               -4750.990229
# SUDESTE                     -4501.941172               -4496.505864
# SUL                         -4898.045911               -4892.360255
#
#               PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO
# REGIÃO
# CENTRO OESTE               -4800.385898                   -4811.263454
# NORDESTE                   -4605.956692                   -4614.345790
# NORTE                      -4749.207684                   -4760.427972
# SUDESTE                    -4493.271157                   -4502.455107
# SUL                        -4889.043826                   -4898.703597

# %%
grupos_regiao.min()
# Out:
#              DATA INICIAL DATA FINAL           PRODUTO  \
# REGIÃO
# CENTRO OESTE   2004-05-09 2004-05-15  ETANOL HIDRATADO
# NORDESTE       2004-05-09 2004-05-15  ETANOL HIDRATADO
# NORTE          2004-05-09 2004-05-15  ETANOL HIDRATADO
# SUDESTE        2004-05-09 2004-05-15  ETANOL HIDRATADO
# SUL            2004-05-09 2004-05-15  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO
# CENTRO OESTE                1.097                    0.0
# NORDESTE                    0.975                    0.0
# NORTE                       1.226                    0.0
# SUDESTE                     0.766                    0.0
# SUL                         0.922                    0.0
#
#               PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# REGIÃO
# CENTRO OESTE                  0.87                 1.099
# NORDESTE                      0.79                 0.999
# NORTE                         1.05                 1.300
# SUDESTE                       0.59                 1.099
# SUL                           0.73                 1.199
#
#               MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# REGIÃO
# CENTRO OESTE              -99999.0                       0.0
# NORDESTE                  -99999.0                       0.0
# NORTE                     -99999.0                       0.0
# SUDESTE                   -99999.0                       0.0
# SUL                       -99999.0                       0.0
#
#               PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                  -99999.0                    -99999.0
# NORDESTE                      -99999.0                    -99999.0
# NORTE                         -99999.0                    -99999.0
# SUDESTE                       -99999.0                    -99999.0
# SUL                           -99999.0                    -99999.0
#
#               PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                   -99999.0                   -99999.0
# NORDESTE                       -99999.0                   -99999.0
# NORTE                          -99999.0                   -99999.0
# SUDESTE                        -99999.0                   -99999.0
# SUL                            -99999.0                   -99999.0
#
#               COEF DE VARIAÇÃO DISTRIBUIÇÃO
# REGIÃO
# CENTRO OESTE                       -99999.0
# NORDESTE                           -99999.0
# NORTE                              -99999.0
# SUDESTE                            -99999.0
# SUL                                -99999.0

# %% [markdown]
# <br/>
#
# Também podemos ter agrupamentos por mais de um atributo.

# %%
regiao_produto = data.groupby(['REGIÃO', 'PRODUTO'])
regiao_produto.groups
# Out:
# {('CENTRO OESTE', 'ETANOL HIDRATADO'): [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], ('CENTRO OESTE', 'GASOLINA ADITIVADA'): [115915, 115917, 115919, 115920, 116090, 116092, 116094, 116095, 116263, 116265, 116267, 116268, 116438, 116440, 116442, 116443, 116615, 116617, 116619, 116620, 116791, 116793, 116795, 116796, 116965, 116967, 116969, 116970, 117139, 117141, 117143, 117144, 117313, 117315, 117317, 117318, 117485, 117487, 117489, 117490, 117662, 117664, 117666, 117667, 117836, 117838, 117840, 117841, 118011, 118013, 118015, 118016, 118187, 118189, 118191, 118192, 118363, 118365, 118367, 118368, 118539, 118541, 118543, 118544, 118716, 118718, 118720, 118721, 118893, 118895, 118897, 118898, 119071, 119073, 119075, 119076, 119248, 119250, 119252, 119253, 119428, 119430, 119432, 119433, 119608, 119610, 119612, 119613, 119786, 119788, 119790, 119791, 119964, 119966, 119968, 119969, 120142, 120144, 120146, 120147, ...], ('CENTRO OESTE', 'GASOLINA COMUM'): [12064, 12065, 12066, 12067, 12091, 12092, 12093, 12094, 12118, 12119, 12120, 12121, 12145, 12146, 12147, 12148, 12172, 12173, 12174, 12175, 12199, 12200, 12201, 12202, 12226, 12227, 12228, 12229, 12253, 12254, 12255, 12256, 12280, 12281, 12282, 12283, 12307, 12308, 12309, 12310, 12334, 12335, 12336, 12337, 12361, 12362, 12363, 12364, 12388, 12389, 12390, 12391, 12415, 12416, 12417, 12418, 12442, 12443, 12444, 12445, 12469, 12470, 12471, 12472, 12496, 12497, 12498, 12499, 12523, 12524, 12525, 12526, 12550, 12551, 12552, 12553, 12577, 12578, 12579, 12580, 12604, 12605, 12606, 12607, 12631, 12632, 12633, 12634, 12658, 12659, 12660, 12661, 12685, 12686, 12687, 12688, 12712, 12713, 12714, 12715, ...], ('CENTRO OESTE', 'GLP'): [24132, 24133, 24134, 24135, 24159, 24160, 24161, 24162, 24186, 24187, 24188, 24189, 24213, 24214, 24215, 24216, 24240, 24241, 24242, 24243, 24267, 24268, 24269, 24270, 24294, 24295, 24296, 24297, 24321, 24322, 24323, 24324, 24348, 24349, 24350, 24351, 24375, 24376, 24377, 24378, 24402, 24403, 24404, 24405, 24429, 24430, 24431, 24432, 24456, 24457, 24458, 24459, 24483, 24484, 24485, 24486, 24510, 24511, 24512, 24513, 24537, 24538, 24539, 24540, 24564, 24565, 24566, 24567, 24591, 24592, 24593, 24594, 24618, 24619, 24620, 24621, 24645, 24646, 24647, 24648, 24672, 24673, 24674, 24675, 24699, 24700, 24701, 24702, 24726, 24727, 24728, 24729, 24753, 24754, 24755, 24756, 24780, 24781, 24782, 24783, ...], ('CENTRO OESTE', 'GNV'): [36196, 36211, 36226, 36241, 36256, 36271, 36286, 36301, 36316, 36331, 36346, 36361, 36377, 36393, 36409, 36425, 36441, 36457, 36473, 36489, 36505, 36521, 36537, 36553, 36569, 36585, 36601, 36617, 36633, 36649, 36665, 36681, 36697, 36713, 36729, 36745, 36761, 36777, 36793, 36809, 36825, 36841, 36857, 36873, 36889, 36905, 36921, 36937, 36953, 36969, 36985, 37001, 37017, 37033, 37049, 37065, 37081, 37097, 37113, 37129, 37145, 37161, 37177, 37193, 37209, 37225, 37242, 37274, 37290, 37307, 37322, 37353, 37368, 37383, 37399, 37415, 37430, 37446, 37462, 37478, 37494, 37510, 37526, 37542, 37558, 37574, 37590, 37606, 37621, 37637, 37653, 37669, 37686, 37702, 37718, 37734, 37750, 37766, 37782, 37798, ...], ('CENTRO OESTE', 'OLEO DIESEL'): [106925, 106927, 106929, 106930, 107075, 107077, 107079, 107080, 107226, 107228, 107230, 107231, 107376, 107378, 107380, 107381, 107526, 107528, 107530, 107531, 107675, 107677, 107679, 107680, 107824, 107826, 107828, 107829, 107973, 107975, 107977, 107978, 108123, 108125, 108127, 108128, 108272, 108274, 108276, 108277, 108422, 108424, 108426, 108427, 108572, 108574, 108576, 108577, 10 ...

# %%
regiao_produto.mean()
# Out:
# C:\Users\Armando\AppData\Local\Temp\ipykernel_3100\79766469.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   regiao_produto.mean()
#                                  NÚMERO DE POSTOS PESQUISADOS  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                      150.655728
#              GASOLINA ADITIVADA                     39.973214
#              GASOLINA COMUM                        150.575445
#              GLP                                   191.095942
#              GNV                                     3.479397
#              OLEO DIESEL                            63.187500
#              OLEO DIESEL S10                        87.204545
#              ÓLEO DIESEL                           131.940332
#              ÓLEO DIESEL S10                        76.054545
# NORDESTE     ETANOL HIDRATADO                      148.186017
#              GASOLINA ADITIVADA                     41.177419
#              GASOLINA COMUM                        167.244176
#              GLP                                   120.881005
#              GNV                                    16.815257
#              OLEO DIESEL                            43.659411
#              OLEO DIESEL S10                        95.311869
#              ÓLEO DIESEL                           135.536185
#              ÓLEO DIESEL S10                        93.857190
# NORTE        ETANOL HIDRATADO                       45.285317
#              GASOLINA ADITIVADA                     18.756477
#              GASOLINA COMUM                         74.600493
#              GLP                                    87.497560
#              GNV                                     1.343042
#              OLEO DIESEL                            30.357143
#              OLEO DIESEL S10                        38.157468
#              ÓLEO DIESEL                            68.135956
#              ÓLEO DIESEL S10                        40.495267
# SUDESTE      ETANOL HIDRATADO                      990.455145
#              GASOLINA ADITIVADA                    227.857143
#              GASOLINA COMUM                       1002.813574
#              GLP                                   718.382454
#              GNV                                    77.265268
#              OLEO DIESEL                           280.326705
#              OLEO DIESEL S10                       446.508523
#              ÓLEO DIESEL                           771.300955
#              ÓLEO DIESEL S10                       419.743514
# SUL          ETANOL HIDRATADO                      427.996943
#              GASOLINA ADITIVADA                    118.738095
#              GASOLINA COMUM                        472.720015
#              GLP                                   461.231300
#              GNV                                    20.491909
#              OLEO DIESEL                           142.136364
#              OLEO DIESEL S10                       221.026515
#              ÓLEO DIESEL                           364.170348
#              ÓLEO DIESEL S10                       230.283597
#
#                                  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO               2.246178               0.114357
#              GASOLINA ADITIVADA             5.094830               0.146732
#              GASOLINA COMUM                 3.222415               0.107976
#              GLP                           51.361335               3.166310
#              GNV                            2.038280               0.033423
#              OLEO DIESEL                    3.713054               0.140094
#              OLEO DIESEL S10                3.813543               0.145886
#              ÓLEO DIESEL                    2.481286               0.081540
#              ÓLEO DIESEL S10                3.294752               0.108976
# NORDESTE     ETANOL HIDRATADO               2.450350               0.119643
#              GASOLINA ADITIVADA             5.069589               0.154085
#              GASOLINA COMUM                 3.156391               0.112682
#              GLP                           45.196169               2.799276
#              GNV                            2.033291               0.064330
#              OLEO DIESEL                    3.678478               0.134749
#              OLEO DIESEL S10                3.732889               0.143567
#              ÓLEO DIESEL                    2.346950               0.069301
#              ÓLEO DIESEL S10                3.041966               0.091881
# NORTE        ETANOL HIDRATADO               2.642997               0.127988
#              GASOLINA ADITIVADA             5.020130               0.126767
#              GASOLINA COMUM                 3.285116               0.142853
#              GLP                           50.835467               2.943641
#              GNV                            2.373379               0.007463
#              OLEO DIESEL                    3.935767               0.186424
#              OLEO DIESEL S10                3.972659               0.191718
#              ÓLEO DIESEL                    2.571048               0.105590
#              ÓLEO DIESEL S10                3.316231               0.127927
# SUDESTE      ETANOL HIDRATADO               2.292143               0.141242
#              GASOLINA ADITIVADA             5.116277               0.209036
#              GASOLINA COMUM                 3.161360               0.126972
#              GLP                           44.860509               3.313045
#              GNV                            1.872572               0.137582
#              OLEO DIESEL                    3.578250               0.166869
#              OLEO DIESEL S10                3.692063               0.176957
#              ÓLEO DIESEL                    2.339699               0.082670
#              ÓLEO DIESEL S10                3.056194               0.109765
# SUL          ETANOL HIDRATADO               2.411797               0.131124
#              GASOLINA ADITIVADA             4.907976               0.202548
#              GASOLINA COMUM                 3.112737               0.123765
#              GLP                           46.543403               3.589349
#              GNV                            2.038801               0.073986
#              OLEO DIESEL                    3.473068               0.160129
#              OLEO DIESEL S10                3.556614               0.176769
#              ÓLEO DIESEL                    2.332293               0.081869
#              ÓLEO DIESEL S10                2.981775               0.110249
#
#                                  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                2.032119              2.552269
#              GASOLINA ADITIVADA              4.787268              5.449670
#              GASOLINA COMUM                  3.004751              3.495984
#              GLP                            43.526536             59.329226
#              GNV                             2.007052              2.067551
#              OLEO DIESEL                     3.446420              4.071264
#              OLEO DIESEL S10                 3.522011              4.214043
#              ÓLEO DIESEL                     2.310497              2.686205
#              ÓLEO DIESEL S10                 3.070625              3.559399
# NORDESTE     ETANOL HIDRATADO                2.223953              2.795075
#              GASOLINA ADITIVADA              4.789581              5.375790
#              GASOLINA COMUM                  2.930183              3.446488
#              GLP                            39.143332             51.407072
#              GNV                             1.969679              2.193925
#              OLEO DIESEL                     3.462612              4.002323
#              OLEO DIESEL S10                 3.467635              4.137511
#              ÓLEO DIESEL                     2.203687              2.534809
#              ÓLEO DIESEL S10                 2.851121              3.304049
# NORTE        ETANOL HIDRATADO                2.459406              2.989098
#              GASOLINA ADITIVADA              4.856601              5.285363
#              GASOLINA COMUM                  3.089484              3.685939
#              GLP                            45.772916             58.159671
#              GNV                             2.368243              2.379793
#              OLEO DIESEL                     3.659252              4.380405
#              OLEO DIESEL S10                 3.708325              4.461097
#              ÓLEO DIESEL                     2.400341              2.831189
#              ÓLEO DIESEL S10                 3.128494              3.645934
# SUDESTE      ETANOL HIDRATADO                1.927714              2.786203
#              GASOLINA ADITIVADA              4.609911              5.849241
#              GASOLINA COMUM                  2.846054              3.645585
#              GLP                            35.709713             54.786829
#              GNV                             1.701172              2.294974
#              OLEO DIESEL                     3.235909              4.235813
#              OLEO DIESEL S10                 3.295466              4.427134
#              ÓLEO DIESEL                     2.118881              2.659866
#              ÓLEO DIESEL S10                 2.765417              3.457892
# SUL          ETANOL HIDRATADO                2.079723              2.841739
#              GASOLINA ADITIVADA              4.483357              5.518131
#              GASOLINA COMUM                  2.811782              3.501471
#              GLP                            37.766601             57.014814
#              GNV                             1.942687              2.232564
#              OLEO DIESEL                     3.165186              3.967932
#              OLEO DIESEL S10                 3.207678              4.162288
#              ÓLEO DIESEL                     2.124973              2.611223
#              ÓLEO DIESEL S10                 2.707439              3.366409
#
#                                  MARGEM MÉDIA REVENDA  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO            -3223.591974
#              GASOLINA ADITIVADA         -99999.000000
#              GASOLINA COMUM              -3212.417264
#              GLP                         -3525.821818
#              GNV                        -11557.247129
#              OLEO DIESEL                -31817.580852
#              OLEO DIESEL S10            -31817.568841
#              ÓLEO DIESEL                     0.269293
#              ÓLEO DIESEL S10                 0.375726
# NORDESTE     ETANOL HIDRATADO            -3584.763993
#              GASOLINA ADITIVADA         -99999.000000
#              GASOLINA COMUM              -3309.566871
#              GLP                         -3488.892533
#              GNV                         -5379.132632
#              OLEO DIESEL                -34186.341565
#              OLEO DIESEL S10            -32827.681467
#              ÓLEO DIESEL                     0.233981
#              ÓLEO DIESEL S10                 0.326030
# NORTE        ETANOL HIDRATADO            -4482.661693
#              GASOLINA ADITIVADA         -99999.000000
#              GASOLINA COMUM              -3256.102668
#              GLP                         -3289.188608
#              GNV                        -18446.105430
#              OLEO DIESEL                -30564.141179
#              OLEO DIESEL S10            -34577.256602
#              ÓLEO DIESEL                     0.323795
#              ÓLEO DIESEL S10                 0.417151
# SUDESTE      ETANOL HIDRATADO            -3324.406438
#              GASOLINA ADITIVADA         -99999.000000
#              GASOLINA COMUM              -3206.940891
#              GLP                         -3171.272230
#              GNV                         -5699.446609
#              OLEO DIESEL                -31817.584341
#              OLEO DIESEL S10            -31817.552293
#              ÓLEO DIESEL                     0.261930
#              ÓLEO DIESEL S10                 0.362285
# SUL          ETANOL HIDRATADO            -3209.436142
#              GASOLINA ADITIVADA         -99999.000000
#              GASOLINA COMUM              -3208.162021
#              GLP                         -3211.384932
#              GNV                         -8367.465845
#              OLEO DIESEL                -31817.573402
#              OLEO DIESEL S10            -31817.550091
#              ÓLEO DIESEL                     0.276743
#              ÓLEO DIESEL S10                 0.368439
#
#                                  COEF DE VARIAÇÃO REVENDA  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                    0.054376
#              GASOLINA ADITIVADA                  0.028598
#              GASOLINA COMUM                      0.033478
#              GLP                                 0.058924
#              GNV                                 0.015592
#              OLEO DIESEL                         0.038324
#              OLEO DIESEL S10                     0.038906
#              ÓLEO DIESEL                         0.032117
#              ÓLEO DIESEL S10                     0.032577
# NORDESTE     ETANOL HIDRATADO                    0.051281
#              GASOLINA ADITIVADA                  0.030532
#              GASOLINA COMUM                      0.036175
#              GLP                                 0.059800
#              GNV                                 0.031670
#              OLEO DIESEL                         0.037396
#              OLEO DIESEL S10                     0.039328
#              ÓLEO DIESEL                         0.029401
#              ÓLEO DIESEL S10                     0.030066
# NORTE        ETANOL HIDRATADO                    0.049844
#              GASOLINA ADITIVADA                  0.025150
#              GASOLINA COMUM                      0.044371
#              GLP                                 0.058427
#              GNV                                 0.002806
#              OLEO DIESEL                         0.048161
#              OLEO DIESEL S10                     0.049161
#              ÓLEO DIESEL                         0.041224
#              ÓLEO DIESEL S10                     0.038669
# SUDESTE      ETANOL HIDRATADO                    0.063585
#              GASOLINA ADITIVADA                  0.041393
#              GASOLINA COMUM                      0.040764
#              GLP                                 0.071048
#              GNV                                 0.073799
#              OLEO DIESEL                         0.047401
#              OLEO DIESEL S10                     0.048551
#              ÓLEO DIESEL                         0.034798
#              ÓLEO DIESEL S10                     0.035397
# SUL          ETANOL HIDRATADO                    0.055662
#              GASOLINA ADITIVADA                  0.041060
#              GASOLINA COMUM                      0.039465
#              GLP                                 0.074754
#              GNV                                 0.033697
#              OLEO DIESEL                         0.046489
#              OLEO DIESEL S10                     0.050216
#              ÓLEO DIESEL                         0.034138
#              ÓLEO DIESEL S10                     0.036409
#
#                                  PREÇO MÉDIO DISTRIBUIÇÃO  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                -3222.112059
#              GASOLINA ADITIVADA             -99999.000000
#              GASOLINA COMUM                  -3210.159063
#              GLP                             -3498.112725
#              GNV                            -11556.419135
#              OLEO DIESEL                    -31815.685480
#              OLEO DIESEL S10                -31815.623682
#              ÓLEO DIESEL                         2.211993
#              ÓLEO DIESEL S10                     2.919026
# NORDESTE     ETANOL HIDRATADO                -3532.013263
#              GASOLINA ADITIVADA             -99999.000000
#              GASOLINA COMUM                  -3307.359915
#              GLP                             -3466.613433
#              GNV                             -5343.689296
#              OLEO DIESEL                    -34184.502449
#              OLEO DIESEL S10                -32825.797869
#              ÓLEO DIESEL                         2.112969
#              ÓLEO DIESEL S10                     2.715936
# NORTE        ETANOL HIDRATADO                -4480.900977
#              GASOLINA ADITIVADA             -99999.000000
#              GASOLINA COMUM                  -3253.863168
#              GLP                             -3258.911293
#              GNV                            -18444.997696
#              OLEO DIESEL                    -30562.154846
#              OLEO DIESEL S10                -34575.364714
#              ÓLEO DIESEL                         2.247253
#              ÓLEO DIESEL S10                     2.899079
# SUDESTE      ETANOL HIDRATADO                -3265.504981
#              GASOLINA ADITIVADA             -99999.000000
#              GASOLINA COMUM                  -3204.654461
#              GLP                             -3150.885143
#              GNV                             -5667.363800
#              OLEO DIESEL                    -31815.777841
#              OLEO DIESEL S10                -31815.726256
#              ÓLEO DIESEL                         2.077769
#              ÓLEO DIESEL S10                     2.693909
# SUL          ETANOL HIDRATADO                -3207.781733
#              GASOLINA ADITIVADA             -99999.000000
#              GASOLINA COMUM                  -3205.926410
#              GLP                             -3188.776740
#              GNV                             -8366.619271
#              OLEO DIESEL                    -31815.862712
#              OLEO DIESEL S10                -31815.823436
#              ÓLEO DIESEL                         2.055550
#              ÓLEO DIESEL S10                     2.613336
#
#                                  DESVIO PADRÃO DISTRIBUIÇÃO  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                  -3223.836285
#              GASOLINA ADITIVADA               -99999.000000
#              GASOLINA COMUM                    -3212.761588
#              GLP                               -3533.116222
#              GNV                              -11557.650819
#              OLEO DIESEL                      -31817.801040
#              OLEO DIESEL S10                  -31817.794608
#              ÓLEO DIESEL                           0.049874
#              ÓLEO DIESEL S10                       0.073233
# NORDESTE     ETANOL HIDRATADO                  -3533.939531
#              GASOLINA ADITIVADA               -99999.000000
#              GASOLINA COMUM                    -3309.904357
#              GLP                               -3496.471708
#              GNV                               -5344.928392
#              OLEO DIESEL                      -34186.539755
#              OLEO DIESEL S10                  -32827.893182
#              ÓLEO DIESEL                           0.048033
#              ÓLEO DIESEL S10                       0.065408
# NORTE        ETANOL HIDRATADO                  -4482.919296
#              GASOLINA ADITIVADA               -99999.000000
#              GASOLINA COMUM                    -3256.479193
#              GLP                               -3296.176698
#              GNV                              -18446.407285
#              OLEO DIESEL                      -30564.416221
#              OLEO DIESEL S10                  -34577.503474
#              ÓLEO DIESEL                           0.060785
#              ÓLEO DIESEL S10                       0.082405
# SUDESTE      ETANOL HIDRATADO                  -3267.271997
#              GASOLINA ADITIVADA               -99999.000000
#              GASOLINA COMUM                    -3207.232654
#              GLP                               -3179.586493
#              GNV                               -5668.464451
#              OLEO DIESEL                      -31817.796503
#              OLEO DIESEL S10                  -31817.788790
#              ÓLEO DIESEL                           0.051781
#              ÓLEO DIESEL S10                       0.078823
# SUL          ETANOL HIDRATADO                  -3209.636707
#              GASOLINA ADITIVADA               -99999.000000
#              GASOLINA COMUM                    -3208.458516
#              GLP                               -3218.611498
#              GNV                               -8367.819142
#              OLEO DIESEL                      -31817.793273
#              OLEO DIESEL S10                  -31817.783856
#              ÓLEO DIESEL                           0.053771
#              ÓLEO DIESEL S10                       0.081475
#
#                                  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                 -3222.277524
#              GASOLINA ADITIVADA              -99999.000000
#              GASOLINA COMUM                   -3210.268450
#              GLP                              -3503.958676
#              GNV                             -11556.438869
#              OLEO DIESEL                     -31815.770184
#              OLEO DIESEL S10                 -31815.730240
#              ÓLEO DIESEL                          2.106889
#              ÓLEO DIESEL S10                      2.779236
# NORDESTE     ETANOL HIDRATADO                 -3532.228552
#              GASOLINA ADITIVADA              -99999.000000
#              GASOLINA COMUM                   -3307.471954
#              GLP                              -3471.181348
#              GNV                              -5343.828050
#              OLEO DIESEL                     -34184.592844
#              OLEO DIESEL S10                 -32825.904060
#              ÓLEO DIESEL                          2.017312
#              ÓLEO DIESEL S10                      2.594516
# NORTE        ETANOL HIDRATADO                 -4481.061772
#              GASOLINA ADITIVADA              -99999.000000
#              GASOLINA COMUM                   -3253.973725
#              GLP                              -3262.561026
#              GNV                             -18445.004247
#              OLEO DIESEL                     -30562.268431
#              OLEO DIESEL S10                 -34575.483202
#              ÓLEO DIESEL                          2.135717
#              ÓLEO DIESEL S10                      2.764806
# SUDESTE      ETANOL HIDRATADO                 -3265.819295
#              GASOLINA ADITIVADA              -99999.000000
#              GASOLINA COMUM                   -3204.853452
#              GLP                              -3157.719328
#              GNV                              -5667.535574
#              OLEO DIESEL                     -31815.923624
#              OLEO DIESEL S10                 -31815.906961
#              ÓLEO DIESEL                          1.931599
#              ÓLEO DIESEL S10                      2.489478
# SUL          ETANOL HIDRATADO                 -3208.089377
#              GASOLINA ADITIVADA              -99999.000000
#              GASOLINA COMUM                   -3206.092598
#              GLP                              -3195.897202
#              GNV                              -8366.759525
#              OLEO DIESEL                     -31815.979103
#              OLEO DIESEL S10                 -31815.971128
#              ÓLEO DIESEL                          1.926497
#              ÓLEO DIESEL S10                      2.438362
#
#                                  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                 -3221.912446
#              GASOLINA ADITIVADA              -99999.000000
#              GASOLINA COMUM                   -3210.003368
#              GLP                              -3492.668657
#              GNV                             -11556.399379
#              OLEO DIESEL                     -31815.580347
#              OLEO DIESEL S10                 -31815.514570
#              ÓLEO DIESEL                          2.323683
#              ÓLEO DIESEL S10                      3.040020
# NORDESTE     ETANOL HIDRATADO                 -3531.810290
#              GASOLINA ADITIVADA              -99999.000000
#              GASOLINA COMUM                   -3307.201108
#              GLP                              -3461.964451
#              GNV                              -5343.538632
#              OLEO DIESEL                     -34184.411683
#              OLEO DIESEL S10                 -32825.670517
#              ÓLEO DIESEL                          2.223088
#              ÓLEO DIESEL S10                      2.865362
# NORTE        ETANOL HIDRATADO                 -4480.735385
#              GASOLINA ADITIVADA              -99999.000000
#              GASOLINA COMUM                   -3253.710685
#              GLP                              -3255.329777
#              GNV                             -18444.988327
#              OLEO DIESEL                     -30562.073287
#              OLEO DIESEL S10                 -34575.241169
#              ÓLEO DIESEL                          2.366200
#              ÓLEO DIESEL S10                      3.047200
# SUDESTE      ETANOL HIDRATADO                 -3265.191823
#              GASOLINA ADITIVADA              -99999.000000
#              GASOLINA COMUM                   -3204.414922
#              GLP                              -3142.103298
#              GNV                              -5667.129840
#              OLEO DIESEL                     -31815.593831
#              OLEO DIESEL S10                 -31815.492500
#              ÓLEO DIESEL                          2.256056
#              ÓLEO DIESEL S10                      2.924680
# SUL          ETANOL HIDRATADO                 -3207.498313
#              GASOLINA ADITIVADA              -99999.000000
#              GASOLINA COMUM                   -3205.705633
#              GLP                              -3179.763711
#              GNV                              -8366.504816
#              OLEO DIESEL                     -31815.701904
#              OLEO DIESEL S10                 -31815.634781
#              ÓLEO DIESEL                          2.207007
#              ÓLEO DIESEL S10                      2.814347
#
#                                  COEF DE VARIAÇÃO DISTRIBUIÇÃO
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                     -3223.869709
#              GASOLINA ADITIVADA                  -99999.000000
#              GASOLINA COMUM                       -3212.798245
#              GLP                                  -3536.121664
#              GNV                                 -11557.659148
#              OLEO DIESEL                         -31817.843688
#              OLEO DIESEL S10                     -31817.842216
#              ÓLEO DIESEL                              0.021995
#              ÓLEO DIESEL S10                          0.024829
# NORDESTE     ETANOL HIDRATADO                     -3533.984629
#              GASOLINA ADITIVADA                  -99999.000000
#              GASOLINA COMUM                       -3309.939651
#              GLP                                  -3498.919350
#              GNV                                  -5344.951565
#              OLEO DIESEL                         -34186.579301
#              OLEO DIESEL S10                     -32827.935053
#              ÓLEO DIESEL                              0.022107
#              ÓLEO DIESEL S10                          0.024048
# NORTE        ETANOL HIDRATADO                     -4482.968579
#              GASOLINA ADITIVADA                  -99999.000000
#              GASOLINA COMUM                       -3256.522030
#              GLP                                  -3297.921212
#              GNV                                 -18446.412738
#              OLEO DIESEL                         -30564.459291
#              OLEO DIESEL S10                     -34577.553904
#              ÓLEO DIESEL                              0.026873
#              ÓLEO DIESEL S10                          0.028042
# SUDESTE      ETANOL HIDRATADO                     -3267.321402
#              GASOLINA ADITIVADA                  -99999.000000
#              GASOLINA COMUM                       -3207.274793
#              GLP                                  -3182.223775
#              GNV                                  -5668.477384
#              OLEO DIESEL                         -31817.841219
#              OLEO DIESEL S10                     -31817.839295
#              ÓLEO DIESEL                              0.023954
#              ÓLEO DIESEL S10                          0.028969
# SUL          ETANOL HIDRATADO                     -3209.690276
#              GASOLINA ADITIVADA                  -99999.000000
#              GASOLINA COMUM                       -3208.499981
#              GLP                                  -3221.963416
#              GNV                                  -8367.849076
#              OLEO DIESEL                         -31817.839303
#              OLEO DIESEL S10                     -31817.836598
#              ÓLEO DIESEL                              0.025223
#              ÓLEO DIESEL S10                          0.030871

# %%
data = pd.read_csv(r'C:\Users\Armando\Downloads\archive\2004-2021.tsv', delimiter = '\t')

# %%
grupos = data.groupby(['REGIÃO'])

# %%
grupos.mean()
# Out:
# C:\Users\Armando\AppData\Local\Temp\ipykernel_3724\1316802999.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grupos.mean()
#               NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# REGIÃO
# CENTRO OESTE                    130.911055            12.440722
# NORDESTE                        117.176934            10.663357
# NORTE                            62.700239            13.411680
# SUDESTE                         673.675402            10.217240
# SUL                             332.741900            10.562091
#
#               DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# REGIÃO
# CENTRO OESTE               0.707499             10.729922
# NORDESTE                   0.606581              9.371222
# NORTE                      0.743323             12.165540
# SUDESTE                    0.701850              8.335308
# SUL                        0.741300              8.771326
#
#               PREÇO MÁXIMO REVENDA  COEF DE VARIAÇÃO REVENDA
# REGIÃO
# CENTRO OESTE             14.217017                  0.040334
# NORDESTE                 12.015522                  0.041201
# NORTE                    15.279058                  0.046625
# SUDESTE                  12.375387                  0.055001
# SUL                      12.743624                  0.047601

# %%
grupos['DESVIO PADRÃO REVENDA'].describe()
# Out:
#                 count      mean       std  min    25%    50%    75%     max
# REGIÃO
# CENTRO OESTE  17449.0  0.707499  1.474681  0.0  0.068  0.112  0.188   9.842
# NORDESTE      41671.0  0.606581  1.288067  0.0  0.065  0.105  0.178  10.748
# NORTE         27989.0  0.743323  1.442045  0.0  0.084  0.143  0.273  10.675
# SUDESTE       19270.0  0.701850  1.411828  0.0  0.095  0.135  0.197   9.632
# SUL           14444.0  0.741300  1.530572  0.0  0.078  0.117  0.188  10.270

# %% [markdown]
# <br/>
#
# `.agg`: **agrega (roda)** uma série de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
import numpy as np

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [np.nan, np.nan, np.nan]],
                  columns=['A', 'B', 'C'])
df
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0
# 3  NaN  NaN  NaN

# %%
df.agg([sum, min])
# Out:
#         A     B     C
# sum  12.0  15.0  18.0
# min   1.0   2.0   3.0

# %%
grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
# Out:
#                 min      max
# REGIÃO
# CENTRO OESTE  1.097  105.194
# NORDESTE      0.975   91.725
# NORTE         1.219  107.500
# SUDESTE       0.766   87.091
# SUL           0.922   91.189

# %% [markdown]
# <h2>6. Ordenação</h2>
# <hr/>

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# `.sort_values()`: ordena valores ao longo de um eixo.

# %%
notas.sort_values(by='idade')
# Out:
#     nome  idade  nota_final
# 2   José     19         6.0
# 0   João     20         5.0
# 3  Alice     20        10.0
# 1  Maria     21        10.0

# %% [markdown]
# Por padrão, o método retorna uma cópia dos dados ordenados em **ordem crescente (ascendente)**. Podemos alterar isso pelo argumento `ascending`.

# %%
notas.sort_values(by='idade', ascending=False)
# Out:
#     nome  idade  nota_final
# 1  Maria     21        10.0
# 0   João     20         5.0
# 3  Alice     20        10.0
# 2   José     19         6.0

# %% [markdown]
# <br/>
#
# Podemos ordenar a partir de **mais de uma coluna**:

# %%
notas.sort_values(by=['nota_final', 'idade'], ascending=[False, True])
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# Ordena os registros, primeiramente, pela coluna 'nota_final' em **ordem descrente**. <br/>
# Então, reordena os registros _"empatados"_, ou seja, com a **mesma nota final**, em _ordem alfabética_ (ordem crescente).

# %% [markdown]
# <br/>
#
# Note que o dataframe original **não foi alterado** após a ordenação.

# %%
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# Para alterá-lo, use o argumento `inplace=True`:

# %%
notas.sort_values(by=['nota_final', 'idade'], ascending=[False, True], inplace = True)

# %%
notas.reset_index(drop=True, inplace=True)

# %%
notas
# Out:
#     nome  idade  nota_final
# 0  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3   João     20         5.0

# %% [markdown]
# <h2>7. Exercícios</h2>
# <hr/>

# %% [markdown]
# Vamos aplicar os conceitos que vimos em alguns exercícios. <br/>
# Para isso, utilizaremos o dataset de _preços de combustíveis no Brasil_.
#
# Como há apenas medições de janeiro a junho para o ano de 2019, resolvemos **remover os dados** deste ano da análise.

# %%
data['ANO'] = data['DATA INICIAL'].dt.year

# %%
data
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO           PRODUTO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 1        2004-05-09 2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 2        2004-05-09 2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 3        2004-05-09 2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 4        2004-05-09 2004-05-15      NORDESTE  ETANOL HIDRATADO
# ...             ...        ...           ...               ...
# 120818   2021-04-25 2021-05-01         NORTE   OLEO DIESEL S10
# 120819   2021-04-25 2021-05-01           SUL   OLEO DIESEL S10
# 120820   2021-04-25 2021-05-01       SUDESTE   OLEO DIESEL S10
# 120821   2021-04-25 2021-05-01      NORDESTE   OLEO DIESEL S10
# 120822   2021-04-25 2021-05-01         NORTE   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                                127              R$/l                1.288
# 1                                387              R$/l                1.162
# 2                                192              R$/l                1.389
# 3                                162              R$/l                1.262
# 4                                103              R$/l                1.181
# ...                              ...               ...                  ...
# 120818                            12              R$/l                4.582
# 120819                           100              R$/l                4.141
# 120820                           886              R$/l                4.246
# 120821                            33              R$/l                4.464
# 120822                            18              R$/l                4.352
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                       0.016                 1.190                 1.350
# 1                       0.114                 0.890                 1.449
# 2                       0.097                 1.180                 1.760
# 3                       0.070                 1.090                 1.509
# 4                       0.078                 1.050                 1.400
# ...                       ...                   ...                   ...
# 120818                  0.056                 4.510                 4.690
# 120819                  0.187                 3.838                 4.739
# 120820                  0.216                 3.769                 5.199
# 120821                  0.205                 4.190                 4.699
# 120822                  0.156                 4.199                 4.699
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                      0.240                     0.066
# ...                      ...                       ...
# 120818            -99999.000                     0.012
# 120819            -99999.000                     0.045
# 120820            -99999.000                     0.051
# 120821            -99999.000                     0.046
# 120822            -99999.000                     0.036
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 120818                -99999.000                  -99999.000
# 120819                -99999.000                  -99999.000
# 120820                -99999.000                  -99999.000
# 120821                -99999.000                  -99999.000
# 120822                -99999.000                  -99999.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 120818                -99999.0000               -99999.00000
# 120819                -99999.0000               -99999.00000
# 120820                -99999.0000               -99999.00000
# 120821                -99999.0000               -99999.00000
# 120822                -99999.0000               -99999.00000
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO   ANO
# 0                               0.133  2004
# 1                               0.115  2004
# 2                               0.098  2004
# 3                               0.143  2004
# 4                               0.082  2004
# ...                               ...   ...
# 120818                     -99999.000  2021
# 120819                     -99999.000  2021
# 120820                     -99999.000  2021
# 120821                     -99999.000  2021
# 120822                     -99999.000  2021
#
# [117392 rows x 18 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  object
#  1   DATA FINAL                     120823 non-null  object
#  2   REGIÃO                         120823 non-null  object
#  3   PRODUTO                        120823 non-null  object
#  4   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  5   UNIDADE DE MEDIDA              120823 non-null  object
#  6   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  7   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  8   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  9   PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  10  MARGEM MÉDIA REVENDA           120823 non-null  object
#  11  COEF DE VARIAÇÃO REVENDA       120823 non-null  float64
#  12  PREÇO MÉDIO DISTRIBUIÇÃO       120823 non-null  object
#  13  DESVIO PADRÃO DISTRIBUIÇÃO     120823 non-null  object
#  14  PREÇO MÍNIMO DISTRIBUIÇÃO      120823 non-null  object
#  15  PREÇO MÁXIMO DISTRIBUIÇÃO      120823 non-null  object
#  16  COEF DE VARIAÇÃO DISTRIBUIÇÃO  120823 non-null  object
# dtypes: float64(5), int64(1), object(11)
# memory usage: 15.7+ MB

# %% [markdown]
# ### 7.1 Qual a quantidade de postos pesquisados para cada combustível em cada região?

# %%
combustiveis = data.groupby(['PRODUTO'])

# %%
df = combustiveis['REGIÃO'].value_counts().to_frame(name='REGISTROS')
df
# Out:
#                                  REGISTROS
# PRODUTO            REGIÃO
# ETANOL HIDRATADO   NORDESTE           7856
#                    NORTE              5982
#                    CENTRO OESTE       3492
#                    SUDESTE            3492
#                    SUL                2618
# GASOLINA ADITIVADA NORDESTE            248
#                    NORTE               193
#                    CENTRO OESTE        112
#                    SUDESTE             112
#                    SUL                  84
# GASOLINA COMUM     NORDESTE           7857
#                    NORTE              6110
#                    CENTRO OESTE       3492
#                    SUDESTE            3492
#                    SUL                2619
# GLP                NORDESTE           7853
#                    NORTE              6110
#                    SUDESTE            3490
#                    CENTRO OESTE       3489
#                    SUL                2619
# GNV                NORDESTE           6180
#                    SUDESTE            3488
#                    SUL                2607
#                    CENTRO OESTE       1671
#                    NORTE               523
# OLEO DIESEL        NORDESTE            781
#                    NORTE               602
#                    CENTRO OESTE        352
#                    SUDESTE             352
#                    SUL                 264
# OLEO DIESEL S10    NORDESTE            792
#                    NORTE               616
#                    CENTRO OESTE        352
#                    SUDESTE             352
#                    SUL                 264
# ÓLEO DIESEL        NORDESTE           7065
#                    NORTE              5494
#                    CENTRO OESTE       3140
#                    SUDESTE            3140
#                    SUL                2355
# ÓLEO DIESEL S10    NORDESTE           3039
#                    NORTE              2359
#                    SUDESTE            1352
#                    CENTRO OESTE       1349
#                    SUL                1014

# %% [markdown]
# ### 7.2 Como os preços da Gasolina Comum no Norte variaram em 2018?

# %%
gasolina_comum = data['PRODUTO'] == 'GASOLINA COMUM'
filtragem = data[gasolina_comum]

# %%
norte = filtragem['REGIÃO'] == 'NORTE'

# %%
filtragem = filtragem[norte]

# %%
ano_2018 = filtragem['ANO'] == 2018

# %%
filtragem = filtragem[ano_2018]

# %%
filtragem.reset_index(drop=True, inplace=True)

# %%
filtragem
# Out:
#     DATA INICIAL DATA FINAL REGIÃO         PRODUTO  \
# 0     2018-01-07 2018-01-13  NORTE  GASOLINA COMUM
# 1     2018-01-07 2018-01-13  NORTE  GASOLINA COMUM
# 2     2018-01-07 2018-01-13  NORTE  GASOLINA COMUM
# 3     2018-01-07 2018-01-13  NORTE  GASOLINA COMUM
# 4     2018-01-07 2018-01-13  NORTE  GASOLINA COMUM
# ..           ...        ...    ...             ...
# 355   2018-12-30 2019-01-05  NORTE  GASOLINA COMUM
# 356   2018-12-30 2019-01-05  NORTE  GASOLINA COMUM
# 357   2018-12-30 2019-01-05  NORTE  GASOLINA COMUM
# 358   2018-12-30 2019-01-05  NORTE  GASOLINA COMUM
# 359   2018-12-30 2019-01-05  NORTE  GASOLINA COMUM
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                              35              R$/l                4.769
# 1                              22              R$/l                4.110
# 2                              71              R$/l                4.293
# 3                             111              R$/l                4.259
# 4                              73              R$/l                4.331
# ..                            ...               ...                  ...
# 355                            73              R$/l                3.888
# 356                           117              R$/l                4.498
# 357                            73              R$/l                4.401
# 358                            13              R$/l                4.058
# 359                            46              R$/l                4.571
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                    0.121                 4.570                 5.150
# 1                    0.219                 3.830                 4.498
# 2                    0.247                 3.890                 4.950
# 3                    0.312                 3.799                 5.040
# 4                    0.131                 4.129                 4.670
# ..                     ...                   ...                   ...
# 355                  0.473                 3.740                 5.050
# 356                  0.278                 3.999                 5.150
# 357                  0.225                 3.989                 4.850
# 358                  0.013                 4.050                 4.080
# 359                  0.311                 3.990                 6.290
#
#      MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                   0.637                     0.025                     4.132
# 1                   0.395                     0.053                     3.715
# 2                   0.672                     0.058                     3.621
# 3                   0.467                     0.073                     3.792
# 4                   0.614                     0.030                     3.717
# ..                    ...                       ...                       ...
# 355                 0.305                     0.122                     3.583
# 356                 0.577                     0.062                     3.921
# 357                 0.619                     0.051                     3.782
# 358                 0.537                     0.003                     3.521
# 359                 0.673                     0.068                     3.898
#
#      DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.092                     4.0010
# 1                         0.052                     3.6409
# 2                         0.133                     3.4000
# 3                         0.142                     3.3587
# 4                         0.083                     3.6097
# ..                          ...                        ...
# 355                       0.206                     3.4000
# 356                       0.072                     3.8124
# 357                       0.086                     3.6600
# 358                       0.099                     3.4150
# 359                       0.042                     3.7800
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO   ANO
# 0                       4.2638                          0.022  2018
# 1                       3.8043                          0.014  2018
# 2                       3.9000                          0.037  2018
# 3                       4.0500                          0.037  2018
# 4                       3.9700                          0.022  2018
# ..                         ...                            ...   ...
# 355                     4.2800                          0.057  2018
# 356                     4.0973                          0.018  2018
# 357                     3.9800                          0.023  2018
# 358                     3.6852                          0.028  2018
# 359                     3.9570                          0.011  2018
#
# [360 rows x 18 columns]

# %% [markdown]
# #### **Estatísticas Descritivas**

# %%
filtragem.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                    360.000000           360.000000
# mean                      53.955556             4.496967
# std                       31.189478             0.332783
# min                       11.000000             3.888000
# 25%                       29.000000             4.266750
# 50%                       46.000000             4.484500
# 75%                       71.000000             4.744250
# max                      117.000000             5.362000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count             360.000000            360.000000            360.000000
# mean                0.176169              4.214339              4.981089
# std                 0.090728              0.321052              0.515425
# min                 0.004000              3.659000              4.080000
# 25%                 0.121000              3.980000              4.589000
# 50%                 0.172500              4.174500              4.950000
# 75%                 0.238250              4.390000              5.250000
# max                 0.473000              5.220000              6.290000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count            360.000000                360.000000
# mean               0.540553                  0.039100
# std                0.166147                  0.020649
# min                0.125000                  0.001000
# 25%                0.467000                  0.027000
# 50%                0.557000                  0.039000
# 75%                0.638000                  0.051000
# max                0.941000                  0.122000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count                360.000000                  360.000000
# mean                   3.956414                    0.091789
# std                    0.234916                    0.038393
# min                    3.521000                    0.007000
# 25%                    3.779000                    0.066750
# 50%                    3.924000                    0.090000
# 75%                    4.120750                    0.115250
# max                    4.614000                    0.217000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count                 360.000000                 360.000000
# mean                    3.792926                   4.135628
# std                     0.243649                   0.261402
# min                     3.169200                   3.624000
# 25%                     3.612325                   3.949700
# 50%                     3.745350                   4.113100
# 75%                     3.953200                   4.284950
# max                     4.423400                   4.914000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO     ANO
# count                     360.000000   360.0
# mean                        0.023194  2018.0
# std                         0.009662     0.0
# min                         0.002000  2018.0
# 25%                         0.017000  2018.0
# 50%                         0.022000  2018.0
# 75%                         0.029000  2018.0
# max                         0.058000  2018.0

# %%
filtragem['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    360.000000
# mean       4.496967
# std        0.332783
# min        3.888000
# 25%        4.266750
# 50%        4.484500
# 75%        4.744250
# max        5.362000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %% [markdown]
# ### 7.3 Como os preços da Gasolina Comum e do Etanol no Norte variaram em 2018?

# %%
etanol  = data['PRODUTO'] == 'ETANOL HIDRATADO'

# %%
filtragem_2 = data[etanol | gasolina_comum]

# %%
norte = filtragem_2['REGIÃO'] == 'NORTE'

# %%
filtragem_2 = filtragem_2[norte]

# %%
ano_2018 = filtragem_2['ANO'] == 2018

# %%
filtragem_2 = filtragem_2[ano_2018]

# %%
filtragem_2.reset_index(drop=True, inplace=True)

# %%
filtragem_2
# Out:
#     DATA INICIAL DATA FINAL REGIÃO           PRODUTO  \
# 0     2018-01-07 2018-01-13  NORTE  ETANOL HIDRATADO
# 1     2018-01-07 2018-01-13  NORTE  ETANOL HIDRATADO
# 2     2018-01-07 2018-01-13  NORTE  ETANOL HIDRATADO
# 3     2018-01-07 2018-01-13  NORTE  ETANOL HIDRATADO
# 4     2018-01-07 2018-01-13  NORTE  ETANOL HIDRATADO
# ..           ...        ...    ...               ...
# 667   2018-12-30 2019-01-05  NORTE    GASOLINA COMUM
# 668   2018-12-30 2019-01-05  NORTE    GASOLINA COMUM
# 669   2018-12-30 2019-01-05  NORTE    GASOLINA COMUM
# 670   2018-12-30 2019-01-05  NORTE    GASOLINA COMUM
# 671   2018-12-30 2019-01-05  NORTE    GASOLINA COMUM
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                              21              R$/l                3.638
# 1                              41              R$/l                3.253
# 2                              38              R$/l                3.620
# 3                              31              R$/l                3.473
# 4                               4              R$/l                3.545
# ..                            ...               ...                  ...
# 667                            73              R$/l                3.888
# 668                           117              R$/l                4.498
# 669                            73              R$/l                4.401
# 670                            13              R$/l                4.058
# 671                            46              R$/l                4.571
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                    0.057                 3.470                  3.75
# 1                    0.209                 3.090                  3.89
# 2                    0.266                 3.240                  4.10
# 3                    0.184                 3.190                  4.01
# 4                    0.064                 3.490                  3.60
# ..                     ...                   ...                   ...
# 667                  0.473                 3.740                  5.05
# 668                  0.278                 3.999                  5.15
# 669                  0.225                 3.989                  4.85
# 670                  0.013                 4.050                  4.08
# 671                  0.311                 3.990                  6.29
#
#      MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                   0.421                     0.016                     3.217
# 1                   0.312                     0.064                     2.941
# 2                   0.423                     0.073                     3.197
# 3                   0.519                     0.053                     2.954
# 4                   0.555                     0.018                     2.990
# ..                    ...                       ...                       ...
# 667                 0.305                     0.122                     3.583
# 668                 0.577                     0.062                     3.921
# 669                 0.619                     0.051                     3.782
# 670                 0.537                     0.003                     3.521
# 671                 0.673                     0.068                     3.898
#
#      DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.012                     3.2082
# 1                         0.112                     2.7000
# 2                         0.121                     3.0609
# 3                         0.088                     2.8965
# 4                         0.030                     2.9465
# ..                          ...                        ...
# 667                       0.206                     3.4000
# 668                       0.072                     3.8124
# 669                       0.086                     3.6600
# 670                       0.099                     3.4150
# 671                       0.042                     3.7800
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO   ANO
# 0                       3.2382                          0.004  2018
# 1                       3.1848                          0.038  2018
# 2                       3.3900                          0.038  2018
# 3                       3.1695                          0.030  2018
# 4                       3.0155                          0.010  2018
# ..                         ...                            ...   ...
# 667                     4.2800                          0.057  2018
# 668                     4.0973                          0.018  2018
# 669                     3.9800                          0.023  2018
# 670                     3.6852                          0.028  2018
# 671                     3.9570                          0.011  2018
#
# [672 rows x 18 columns]

# %% [markdown]
# <h2>8. Assuntos para continuar os estudos</h2>
# <hr/>
#
# - join
# - concat
# - plot
# - data cleaning
